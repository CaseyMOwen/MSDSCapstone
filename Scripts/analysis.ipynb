# %%
import pickle
import pandas as pd
import processingfuncs as pf
from sklearn.inspection import permutation_importance
import xgboost as xgb
from sklearn.pipeline import Pipeline

url = 'https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/resstock_dataset_2024.1/resstock_tmy3/metadata_and_annual_results/national/parquet/Baseline/baseline_metadata_and_annual_results.parquet'

# df = pd.read_parquet(url)
df = pd.read_parquet('first_500.parquet')
in_cols = [col for col in df.columns if col.startswith('in')]
out_cols = [col for col in df.columns if col.startswith('out')]
df['out.electricity.total.energy_consumption.kwh'] = df['out.electricity.total.energy_consumption.kwh'].clip(0,None)

X, y = df[in_cols], df['out.electricity.total.energy_consumption.kwh']
X = pf.preprocess_columns(X)
X = pf.add_tmy3_data(X)


with open('Jobs/2024-07-30/xgboost/xgb_model_cold_baseline.pkl', 'rb') as f:
        model = pickle.load(f)

with open('Jobs/2024-07-30/pipeline_cold.pkl', 'rb') as f:
        pipeline = pickle.load(f)

class convert_to_dmatrix():
    def __init__(self) -> None:
           pass
    
    def transform(self, X):
           return xgb.DMatrix(X)

converter = convert_to_dmatrix()

pipeline.steps.append(['converter', converter])
pipeline.steps.append(['estimator', model])
pipeline.named_steps
# result = permutation_importance(pipeline, X, y, n_jobs=-1, scoring='neg_root_mean_squared_error')

# X_clean = pipeline.transform(X)


# feature_important = model.get_score(importance_type='weight')
# keys = list(feature_important.keys())
# values = list(feature_important.values())

# data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
# data.nlargest(40, columns="score").plot(kind='barh', figsize = (20,10)) ## plot top 40 features
# Out:
# {'preprocessor': ColumnTransformer(remainder='passthrough',
#                    transformers=[('binary',
#                                   BinaryEncoder(cols=['in.building_america_climate_zone',
#                                                       'in.clothes_dryer',
#                                                       'in.clothes_washer_presence',
#                                                       'in.cooking_range',
#                                                       'in.cooling_setpoint_has_offset',
#                                                       'in.cooling_setpoint_offset_period',
#                                                       'in.corridor',
#                                                       'in.dishwasher',
#                                                       'in.duct_location',
#                                                       'in.geometry_attic_type',
#                                                       'in.geometry_buildi...
#                                    'in.insulation_floor',
#                                    'in.insulation_foundation_wall',
#                                    'in.insulation_rim_joist',
#                                    'in.insulation_roof', 'in.insulation_slab',
#                                    'in.misc_extra_refrigerator', 'in.neighbors',
#                                    'in.occupants', 'in.pv_system_size',
#                                    'in.range_spot_vent_hour', 'in.refrigerator', ...]),
#                                  ('catboost',
#                                   CatBoostEncoder(cols=['in.county', 'in.state'],
#                                                   drop_invariant=True),
#                                   ['in.county', 'in.state'])]),
#  'scaler': MinMaxScaler(),
#  'converter': <__main__.convert_to_dmatrix at 0x721945a1fee0>,
#  'estimator': <xgboost.core.Booster at 0x72198a9d9840>}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle

with open('Jobs/2024-08-10_importance/importance_result.pkl', 'rb') as f:
        result = pickle.load(f)


# for i in range(2):
sorted_importances_idx = result.importances_mean.argsort()[90:]
importances = pd.DataFrame(result.importances[sorted_importances_idx].T, columns=X.columns[sorted_importances_idx])
plt.figure(figsize=(40,8))
ax = importances.plot.box(vert=False, whis=10)
ax.set_title("Permutation Importances (test set)")
ax.axvline(x=0, color="k", linestyle="--")
ax.set_xlabel("Decrease in accuracy score")
ax.figure.tight_layout()
plt.show()
# importance_means = pd.DataFrame(result.importances_mean, columns=X.columns)
# print(importance_means.T)
# print(result.importances_mean)
# plt.savefig('importances.png', bbox_inches='tight', dpi=100)
print(importances)
# for r, i in enumerate(result):
#     print(f'Column: {}')
# Out:
#    in.misc_pool  in.cooling_setpoint         cdd  in.lighting   in.tenure  \
# 0    147.276001           181.622821  224.604921   231.534579  241.926988
# 1    147.713423           181.554964  223.817007   231.937725  239.957695
# 2    147.156931           181.565314  223.617002   231.030782  239.818174
# 3    146.959703           181.115715  223.726866   231.889326  242.196804
# 4    147.156379           181.404622  223.658685   232.224792  240.957431
#
#    in.hvac_heating_efficiency  in.vintage  in.insulation_roof  \
# 0                  281.329125  299.009627          320.335443
# 1                  282.793714  298.900787          319.318624
# 2                  280.911089  301.185703          319.947989
# 3                  281.395508  301.778889          319.757800
# 4                  280.683816  300.474526          320.946383
#
#    in.insulation_ceiling  in.hvac_cooling_partial_space_conditioning  ...  \
# 0             358.036577                                  402.655413  ...
# 1             357.894325                                  402.717580  ...
# 2             357.079414                                  404.180451  ...
# 3             359.027064                                  403.473618  ...
# 4             357.132953                                  404.110707  ...
#
#    in.household_has_tribal_persons    min temp  in.heating_setpoint  \
# 0                       470.524257  667.976662           715.216344
# 1                       470.789749  667.241511           716.382754
# 2                       471.130591  665.100825           715.610978
# 3                       470.096325  666.122811           713.386678
# 4                       469.911486  668.125224           715.255913
#
#    in.water_heater_fuel  in.infiltration  in.clothes_dryer_usage_level  \
# 0            793.351532       969.647714                   1041.557167
# 1            795.893253       969.514128                   1044.031948
# 2            793.147155       968.423551                   1043.547601
# 3            791.972610       969.960144                   1043.216943
# 4            790.618743       960.653864                   1044.396343
#
#    in.occupants          hdd  in.geometry_floor_area  in.heating_fuel
# 0   1096.105703  1351.628540             3605.537995      5209.520258
# 1   1091.697856  1354.584879             3599.647538      5215.865746
# 2   1091.255117  1351.329434             3619.394950      5206.324000
# 3   1093.548412  1350.176884             3613.636151      5199.840746
# 4   1093.792608  1354.801185             3606.607093      5210.238089
#
# [5 rows x 21 columns]

# %%
from pyathena import connect
import pandas as pd
from API.config import Aws as aws
access_key = aws.ACCESS_KEY
secret_key = aws.SECRET_KEY
url = aws.S3_STAGING_DIR
conn = connect(
                aws_access_key_id=access_key,
                aws_secret_access_key=secret_key,
                s3_staging_dir=url,
                region_name=aws.REGION)
df = pd.read_sql_query("SELECT * FROM \"resstock\".\"resstock_dataset_2024.1parquet\" WHERE upgrade='0' limit 9;", conn)
print(df.head())
# Out:
# /tmp/ipykernel_219260/433317053.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM \"resstock\".\"resstock_dataset_2024.1parquet\" WHERE upgrade='0' limit 9;", conn)
#   upgrade     weight  applicability  in.sqft  \
# 0       0  63.075295           True    623.0
# 1       0  63.075295           True    854.0
# 2       0  63.075295           True    854.0
# 3       0  63.075295           True   2678.0
# 4       0  63.075295           True   1138.0
#
#                                     in.ahs_region in.aiannh_area  \
# 0                CBSA Seattle-Tacoma-Bellevue, WA             No
# 1      CBSA New York-Newark-Jersey City, NY-NJ-PA             No
# 2  CBSA Miami-Fort Lauderdale-West Palm Beach, FL             No
# 3                     Non-CBSA West North Central             No
# 4      CBSA New York-Newark-Jersey City, NY-NJ-PA             No
#
#   in.area_median_income in.ashrae_iecc_climate_zone_2004  \
# 0         Not Available                               4C
# 1                60-80%                               4A
# 2                30-60%                               1A
# 3               80-100%                               4A
# 4                 150%+                               4A
#
#   in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  ...  \
# 0                                         4C                     Hour19  ...
# 1                                         4A                      Hour3  ...
# 2                                         1A                      Hour0  ...
# 3                                         4A                     Hour23  ...
# 4                                         4A                      Hour4  ...
#
#   upgrade.insulation_wall upgrade.infiltration upgrade.insulation_roof  \
# 0                    None                 None                    None
# 1                    None                 None                    None
# 2                    None                 None                    None
# 3                    None                 None                    None
# 4                    None                 None                    None
#
#   upgrade.insulation_sheathing upgrade.mechanical_ventilation  \
# 0                         None                           None
# 1                         None                           None
# 2                         None                           None
# 3                         None                           None
# 4                         None                           None
#
#   upgrade.water_heater_efficiency upgrade.water_heater_fuel  \
# 0                            None                      None
# 1                            None                      None
# 2                            None                      None
# 3                            None                      None
# 4                            None                      None
#
#   upgrade.hvac_heating_type_and_fuel upgrade.heating_fuel partition_0
# 0                               None                 None    Baseline
# 1                               None                 None    Baseline
# 2                               None                 None    Baseline
# 3                               None                 None    Baseline
# 4                               None                 None    Baseline
#
# [5 rows x 396 columns]

# %%
from urllib.parse import quote_plus
from sqlalchemy.engine import create_engine
import pandas as pd
from API.config import Aws as aws

query = "SELECT * FROM \"resstock\".\"resstock_dataset_2024.1parquet\" WHERE upgrade='0' limit 9;"

conn_str = (
    "awsathena+rest://{aws_access_key_id}:{aws_secret_access_key}@"
    "athena.{region_name}.amazonaws.com:443/"
    "{schema_name}?s3_staging_dir={s3_staging_dir}&work_group=primary"
)


# Create the SQLAlchemy connection. Note that you need to have pyathena installed for this.
engine = create_engine(
    conn_str.format(
        aws_access_key_id=quote_plus(aws.ACCESS_KEY),
        aws_secret_access_key=quote_plus(aws.SECRET_KEY),
        region_name=aws.REGION,
        schema_name=aws.SCHEMA_NAME,
        s3_staging_dir=quote_plus(aws.S3_STAGING_DIR),
    )
)
athena_connection = engine.connect()
df_data = pd.read_sql_query(query, athena_connection)
df_data
# Out:
# /tmp/ipykernel_193547/569441184.py:20: SADeprecationWarning: The dbapi() classmethod on dialect classes has been renamed to import_dbapi().  Implement an import_dbapi() classmethod directly on class <class 'pyathena.sqlalchemy.rest.AthenaRestDialect'> to remove this warning; the old .dbapi() classmethod may be maintained for backwards compatibility.
#   engine = create_engine(
#      _col0
# 0  in.sqft
# 1  in.sqft
# 2  in.sqft
# 3  in.sqft
# 4  in.sqft
# 5  in.sqft
# 6  in.sqft
# 7  in.sqft
# 8  in.sqft

# %%
import pandas as pd
from pyathena import connect
from pyathena.pandas.cursor import PandasCursor
from config import Aws as aws
query = 'SELECT * FROM "resstock"."release_2024.1by_state" WHERE "state"=\'FL\' AND "measure_group"=\'Baseline\' AND "in.county"=\'G1200090\' limit 10'
cursor = connect(aws_access_key_id=aws.ACCESS_KEY,
                 aws_secret_access_key=aws.SECRET_KEY,
                s3_staging_dir=aws.S3_STAGING_DIR,
                region_name=aws.REGION,
                cursor_class=PandasCursor).cursor()
df = cursor.execute(query).as_pandas()
df
# Out:
#   upgrade     weight  applicability  in.sqft            in.ahs_region  \
# 0       0  63.075295           True   1698.0  Non-CBSA South Atlantic
# 1       0  63.075295           True   3310.0  Non-CBSA South Atlantic
# 2       0  63.075295           True   2678.0  Non-CBSA South Atlantic
# 3       0  63.075295           True   1698.0  Non-CBSA South Atlantic
# 4       0  63.075295           True   1138.0  Non-CBSA South Atlantic
# 5       0  63.075295           True   1698.0  Non-CBSA South Atlantic
# 6       0  63.075295           True   1698.0  Non-CBSA South Atlantic
# 7       0  63.075295           True   3310.0  Non-CBSA South Atlantic
# 8       0  63.075295           True   1138.0  Non-CBSA South Atlantic
# 9       0  63.075295           True   1207.0  Non-CBSA South Atlantic
#
#   in.aiannh_area in.area_median_income in.ashrae_iecc_climate_zone_2004  \
# 0             No                 150%+                               2A
# 1             No                 150%+                               2A
# 2             No                 150%+                               2A
# 3             No              120-150%                               2A
# 4             No         Not Available                               2A
# 5             No              120-150%                               2A
# 6             No               80-100%                               2A
# 7             No         Not Available                               2A
# 8             No         Not Available                               2A
# 9             No              120-150%                               2A
#
#   in.ashrae_iecc_climate_zone_2004_2_a_split in.bathroom_spot_vent_hour  ...  \
# 0                        2A - FL, GA, AL, MS                      Hour6  ...
# 1                        2A - FL, GA, AL, MS                      Hour5  ...
# 2                        2A - FL, GA, AL, MS                     Hour15  ...
# 3                        2A - FL, GA, AL, MS                     Hour17  ...
# 4                        2A - FL, GA, AL, MS                     Hour21  ...
# 5                        2A - FL, GA, AL, MS                      Hour4  ...
# 6                        2A - FL, GA, AL, MS                     Hour13  ...
# 7                        2A - FL, GA, AL, MS                      Hour4  ...
# 8                        2A - FL, GA, AL, MS                      Hour7  ...
# 9                        2A - FL, GA, AL, MS                      Hour4  ...
#
#   upgrade.cooling_setpoint_offset_magnitude  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#   upgrade.cooling_setpoint_offset_period upgrade.heating_setpoint_has_offset  \
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# 5                                    NaN                                 NaN
# 6                                    NaN                                 NaN
# 7                                    NaN                                 NaN
# 8                                    NaN                                 NaN
# 9                                    NaN                                 NaN
#
#   upgrade.heating_setpoint_offset_magnitude  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#   upgrade.heating_setpoint_offset_period  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
#
#   upgrade.hvac_secondary_heating_efficiency  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#   upgrade.hvac_secondary_heating_fuel state file_type measure_group
# 0                                 NaN    FL   parquet      Baseline
# 1                                 NaN    FL   parquet      Baseline
# 2                                 NaN    FL   parquet      Baseline
# 3                                 NaN    FL   parquet      Baseline
# 4                                 NaN    FL   parquet      Baseline
# 5                                 NaN    FL   parquet      Baseline
# 6                                 NaN    FL   parquet      Baseline
# 7                                 NaN    FL   parquet      Baseline
# 8                                 NaN    FL   parquet      Baseline
# 9                                 NaN    FL   parquet      Baseline
#
# [10 rows x 409 columns]

# %%
import pandas as pd
# url = 'https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/resstock_dataset_2024.1/resstock_tmy3/metadata_and_annual_results/national/parquet/Baseline/baseline_metadata_and_annual_results.parquet'
url = 'https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/resstock_dataset_2024.1/resstock_tmy3/metadata_and_annual_results/by_state/state=AL/parquet/Baseline/AL_baseline_metadata_and_annual_results.parquet'


df = pd.read_parquet(url)

# %%
import polars as pl

# url = 'https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/resstock_dataset_2024.1/resstock_tmy3/metadata_and_annual_results/national/parquet/Baseline/baseline_metadata_and_annual_results.parquet'
url = 'https://oedi-data-lake.s3.amazonaws.com/nrel-pds-building-stock/end-use-load-profiles-for-us-building-stock/2024/resstock_dataset_2024.1/resstock_tmy3/metadata_and_annual_results/by_state/state=AL/parquet/Baseline/AL_baseline_metadata_and_annual_results.parquet'

df = pl.read_parquet(url, parallel='row_groups', use_pyarrow=True)

# %%
import os
import pandas as pd
import re

def to_underscore_case(s):
    # Replace '::' with '/'
    s = s.replace('::', '/')
    
    # Convert CamelCase to snake_case
    s = re.sub(r'([a-z\d])([A-Z])', r'\1_\2', s)
    s = re.sub(r'([A-Z]+)([A-Z][a-z])', r'\1_\2', s)
    
    # Replace '-' and ' ' with '_'
    s = s.replace('-', '_').replace(' ', '_')
    
    # Convert to lowercase
    s = s.lower()
    
    return "in." + s



directory = '/home/casey/Documents/Graduate_School/Masters_Project/Data/housing_characteristics/2022_1'
results = []
for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path, sep='\t')
        # print(df.columns.to_list())
        columnlist = df.columns.to_list()
        results.append([
            filename,
            to_underscore_case(filename.split('.')[0]),
            filename.split('.')[0],
            '|'.join([item.split('=')[1] for item in columnlist if item.startswith('Dependency')]),
            '|'.join([item.split('=')[1] for item in columnlist if item.startswith('Option')]),
        ])
        # break
# print(results)
results_df = pd.DataFrame(results, columns=['Filename', 'UnderscoreCase', 'CapitalCase', 'Dependencies', 'Options'])
results_df.to_csv('2022_dependencies.csv')

'''
  def to_underscore_case
    gsub(/::/, '/')
      .gsub(/([A-Z]+)([A-Z][a-z])/, '\1_\2')
      .gsub(/([a-z\d])([A-Z])/, '\1_\2')
      .tr('-', '_')
      .tr(' ', '_')
      .downcase
  end

'''
# Out:
# "\n  def to_underscore_case\n    gsub(/::/, '/')\n      .gsub(/([A-Z]+)([A-Z][a-z])/, '\x01_\x02')\n      .gsub(/([a-z\\d])([A-Z])/, '\x01_\x02')\n      .tr('-', '_')\n      .tr(' ', '_')\n      .downcase\n  end\n\n"

# %%
# For row in dependencies list:
# Check 
import random
import json
import numpy as np
import itertools
import numexpr as ne
import pandas as pd
import re

def to_underscore_case(s):
    # Replace '::' with '/'
    s = s.replace('::', '/')
    
    # Convert CamelCase to snake_case
    s = re.sub(r'([a-z\d])([A-Z])', r'\1_\2', s)
    s = re.sub(r'([A-Z]+)([A-Z][a-z])', r'\1_\2', s)
    
    # Replace '-' and ' ' with '_'
    s = s.replace('-', '_').replace(' ', '_')
    
    # Convert to lowercase
    s = s.lower()
    
    return "in." + s

# Feats is dictionary with unserscore case field names, and value as value

def generate_sample(feats={'in.county':'G1200090', 'in.bedrooms':'2'}, num_samples=5):
# For each row in dependencies list - check if we have what we need for this column, and if we need it. If so, add a column to the samples df, each of correct distribution according to the existing row
    
    
    if not "in.county" in feats:
        raise ValueError("feats must include at least in.county as a key")
    
    with open('resstock_county_lookup.json') as json_file:
        gispuma_lookup = json.load(json_file)

    gispuma = gispuma_lookup[feats["in.county"]]
    del feats["in.county"]
    feats["in.county_and_puma"] = gispuma
    dep_df = pd.read_csv('dependencies.csv')
    column_plan_df = pd.read_csv('column_plan.csv', usecols=['field_name','keep_for_model'])
    # List of columns that the model requires as inputs
    needed_und_cols = column_plan_df.loc[
        (column_plan_df['keep_for_model'] == 'Yes') | 
        (column_plan_df['keep_for_model'] == 'Split')
    ]['field_name'].to_list()
    needed_und_cols.append("in.county_and_puma")
    # Initialize with known parameters
    sample_df = pd.DataFrame()
    sample_df.index.name = 'bldg_id'
    for key in feats:
        sample_df[key] = [feats[key]]*num_samples
        needed_und_cols.remove(key)
    
    # print(sample_df)
    # print(dep_df.columns)
    known_cap_cols  = set(dep_df[dep_df['UnderscoreCase'].isin(feats.keys())]['CapitalCase'].to_list())
    needed_cap_cols = set(dep_df[dep_df['UnderscoreCase'].isin(needed_und_cols)]['CapitalCase'].to_list())
    # print(model_cols)
    # print(cap_model_cols)
    # print(known_cap_cols)
    # print(needed_cap_cols)
    iter = 0
    while needed_cap_cols:
        iter += 1
        print(f'iter: {iter}, needed_cap_cols: {needed_cap_cols}')
        print(f'iter: {iter}, known_cap_cols: {known_cap_cols}')
        for i, field in dep_df['CapitalCase'].items():
            if field not in needed_cap_cols or field in known_cap_cols:
                continue
            dep_str = dep_df.loc[i, 'Dependencies']
            # print(dep_str)
            if pd.isnull(dep_str):
                dependencies = []
            else:
                dependencies = dep_str.split('|')
            
            if any(x not in known_cap_cols for x in dependencies):
                # Set difference - only add dependencies not already known
                needed_cap_cols.update(set(dependencies) - known_cap_cols)
                continue
            else: #All dependencies are already in sample_df
                sample_df = add_col_to_sample(sample_df, field, dependencies)
                needed_cap_cols.remove(field)
                known_cap_cols.add(field)
        if iter > 500:
            break
            # print(field)
            # print(dependencies)
            # break
        # break
    sample_df.to_csv('sample_test.csv')
# Updates needed_cap_cols to also include dependencies necessary
# def collect_all_dependencies(dep_df, cap_name):
#     dependencies = 
#     if 


def add_col_to_sample(sample_df: pd.DataFrame, cap_field, cap_dependencies):
    # directory = '/home/casey/Repos/ResStock/resstock/project_national/housing_characteristics'
    directory = '/home/casey/Documents/Graduate_School/Masters_Project/API/appfiles/housing_characteristics'
    # char_df = pd.read_csv(directory + '/' + cap_field + '.tsv', sep='\t',  keep_default_na=False, dtype='str', engine='c')
    char_df = pd.read_parquet(directory + '/' + cap_field + '.parquet')
    print(f'Adding field: {cap_field}')
    # print(char_df)
    # char_df = char_df[~char_df.iloc[:, 0].str.startswith('#', na=False)]
    # Speed up - only do this once for each unique combo of dependencies
    num_points = sample_df.shape[0]
    samples_dict = {}
    # Special case where there are no dependencies - only top row matters
    options = [col.split('Option=')[1] for col in char_df.columns if col.startswith('Option=')]
    if not cap_dependencies:
        # options = []
        # probs = []
        # for col in char_df:
        #     if col.startswith('Option='):
        #         options.append(col.split('Option=')[1])
        #         probs.append(float(char_df[col].values[0]))
        # options = [col.split('Option=')[1] for col in char_df.columns if col.startswith('Option=')]
        # options = char_df.columns[char_df.columns.str.startswith('Option=')].split('Option=')[1]

        probs = char_df.loc[0,char_df.columns.str.startswith('Option=')].to_numpy(dtype=float)
        # print(probs)
        # probs = np.array([float(char_df[col].values[0]) for col in char_df.columns if col.startswith('Option=')])

        # Normalize to sum to 1
        probs /= np.sum(probs)
        sample_df[to_underscore_case(cap_field)] = np.random.choice(options, p=probs, size=num_points,replace=True)
        return sample_df
    
    und_dependencies = [to_underscore_case(d) for d in cap_dependencies]
    # Dataframe of all unique combinations of dependencies - these are the only ones we will need to generate a random array for
    # print(f'Now Adding column for: {cap_field}')
    # print(f'Sample df: {sample_df}')
    unique_dep_combos_df = sample_df[und_dependencies].drop_duplicates()
    for i in range(unique_dep_combos_df.shape[0]):
        # dictionary of the combo of dependencies and their values, in underscore case
        und_dep_combo = unique_dep_combos_df.iloc[i][und_dependencies].to_dict()
        # print(und_dep_combo)
        # cap_dep_combo = {}
        # for dep in cap_dependencies:
        #     und_dep = to_underscore_case(dep)
        #     if und_dep in und_dep_combo:
        #         cap_dep_combo['Dependency='+dep] = und_dep_combo[und_dep]

        cap_dep_combo = {'Dependency=' + dep: und_dep_combo[to_underscore_case(dep)] for dep in cap_dependencies if to_underscore_case(dep) in und_dep_combo}
        query_str = ''
        first_append = True
        for dep in cap_dependencies:
                und_dep = to_underscore_case(dep)
                # if len(cap_dependencies) > 1:
                #     pass
                if und_dep in und_dep_combo:
                    cap_dep_combo['Dependency='+dep] = und_dep_combo[und_dep]
                    if not first_append:
                        query_str += ' and '
                    else:
                        first_append = False
                    query_str += '(`Dependency='+dep + '` == "' +und_dep_combo[und_dep] +  '")'

        # print(query_str)
        
        # print(cap_dep_combo)
        # for key in dep_combo:
        #     formatted_dep_combo['Dependency='+key] = dep_combo[key]
        #     del dep_combo[key]

        # The row of the tsv file that matches all dependencies
        # characteristic_row = char_df.loc[(char_df[cap_dep_combo.keys()] == pd.Series(cap_dep_combo)).all(axis=1)]
        characteristic_row = char_df.query(query_str, engine='numexpr')

        # The list of building ids that have this combo
        bldg_ids = sample_df.loc[(sample_df[und_dep_combo.keys()] == pd.Series(und_dep_combo)).all(axis=1)].index.to_list()
        # print(sample_df[und_dependencies])
        # print(f'Building ids: {bldg_ids}')
        # characteristic_row.reset_index()
        # print(cap_field)
        # print(row)
        # print(characteristic_row)
        # options = []
        # probs = []
        # for col in characteristic_row:
        #     if col.startswith('Option='):
        #         options.append(col.split('Option=')[1])
        #         probs.append(float(characteristic_row[col].values[0]))
        # options = [col.split('Option=')[1] for col in char_df.columns if col.startswith('Option=')]
        # probs = np.array([float(char_df[col].values[0]) for col in char_df.columns if col.startswith('Option=')])
        probs = characteristic_row.iloc[0][char_df.columns.str.startswith('Option=')].to_numpy(dtype=float)
        # probs = np.array(probs)
        probs /= np.sum(probs)

        # col_values.append(random.choices(options, weights=probs, k=1)[0])
        samples = np.random.choice(options, p=probs, size=num_points, replace=True)
        this_samples_dict = dict(zip(bldg_ids, samples))
        samples_dict.update(this_samples_dict)
        # break
    # sample_df[to_underscore_case(cap_field)] = col_values
    new_column = pd.DataFrame.from_dict(samples_dict, orient='index', columns=[to_underscore_case(cap_field)])
    # print(new_column)
    # sample_df.join(new_column)
    return sample_df.join(new_column)
        
        

generate_sample(num_samples=10)
# Out:
# iter: 1, needed_cap_cols: {'Clothes Dryer Usage Level', 'Geometry Stories', 'Misc Hot Tub Spa', 'Duct Leakage and Insulation', 'Occupants', 'Geometry Attic Type', 'Geometry Wall Type', 'Misc Well Pump', 'Misc Pool Heater', 'Insulation Roof', 'Usage Level', 'HVAC Cooling Type', 'Lighting', 'Water Heater Fuel', 'HVAC Heating Efficiency', 'Clothes Washer Presence', 'Geometry Garage', 'Insulation Rim Joist', 'HVAC Cooling Efficiency', 'Insulation Slab', 'Geometry Floor Area', 'Clothes Washer Usage Level', 'Geometry Building Type Height', 'Geometry Building Type ACS', 'Orientation', 'Water Heater In Unit', 'Range Spot Vent Hour', 'Misc Gas Lighting', 'County', 'Water Heater Efficiency', 'Misc Extra Refrigerator', 'Window Areas', 'Dishwasher', 'HVAC Has Zonal Electric Heating', 'State', 'Household Has Tribal Persons', 'Cooking Range Usage Level', 'Duct Location', 'Geometry Stories Low Rise', 'Geometry Building Number Units SFA', 'Heating Setpoint Has Offset', 'PV System Size', 'Cooking Range', 'Ceiling Fan', 'Cooling Setpoint Offset Period', 'Clothes Washer', 'Misc Gas Grill', 'PV Orientation', 'HVAC Cooling Partial Space Conditioning', 'Infiltration', 'Misc Gas Fireplace', 'Misc Freezer', 'Corridor', 'Insulation Wall', 'Bathroom Spot Vent Hour', 'Geometry Foundation Type', 'Misc Pool Pump', 'Tenure', 'Geometry Building Horizontal Location MF', 'Neighbors', 'Cooling Setpoint Offset Magnitude', 'HVAC Has Ducts', 'Misc Pool', 'Has PV', 'HVAC Heating Type', 'Windows', 'Refrigerator Usage Level', 'Clothes Dryer', 'Heating Setpoint Offset Period', 'Cooling Setpoint Has Offset', 'Radiant Barrier', 'Geometry Building Horizontal Location SFA', 'Insulation Ceiling', 'Insulation Foundation Wall', 'Insulation Floor', 'Heating Setpoint Offset Magnitude', 'Geometry Wall Exterior Finish', 'Heating Setpoint', 'Cooling Setpoint', 'Roof Material', 'HVAC Heating Type And Fuel', 'Refrigerator', 'Geometry Building Level MF', 'Geometry Building Number Units MF', 'Vintage', 'Hot Water Fixtures', 'HVAC Shared Efficiencies', 'Vacancy Status', 'HVAC Has Shared System', 'Heating Fuel'}
# iter: 1, known_cap_cols: {'County and PUMA', 'Bedrooms'}
# Adding field: Misc Well Pump
# Adding field: Misc Gas Lighting
# Adding field: Misc Gas Grill
# Adding field: ASHRAE IECC Climate Zone 2004
# Adding field: Usage Level
# Adding field: Range Spot Vent Hour
# Adding field: Bathroom Spot Vent Hour
# Adding field: Clothes Washer Usage Level
# Adding field: Clothes Dryer Usage Level
# Adding field: Orientation
# Adding field: Hot Water Fixtures
# Adding field: County
# Adding field: State
# Adding field: Misc Gas Fireplace
# Adding field: PUMA
# iter: 2, needed_cap_cols: {'Federal Poverty Level', 'Geometry Stories', 'Misc Hot Tub Spa', 'Geometry Floor Area Bin', 'Vintage ACS', 'Geometry Story Bin', 'Duct Leakage and Insulation', 'Occupants', 'Geometry Attic Type', 'Geometry Wall Type', 'Misc Pool Heater', 'Insulation Roof', 'HVAC Cooling Type', 'Lighting', 'Water Heater Fuel', 'Income RECS2015', 'HVAC Heating Efficiency', 'Clothes Washer Presence', 'Geometry Garage', 'Census Division', 'Insulation Rim Joist', 'HVAC Cooling Efficiency', 'Insulation Slab', 'Geometry Floor Area', 'Income RECS2020', 'Geometry Building Type Height', 'Geometry Building Type ACS', 'Water Heater In Unit', 'Water Heater Efficiency', 'Misc Extra Refrigerator', 'Window Areas', 'Dishwasher', 'Location Region', 'HVAC Has Zonal Electric Heating', 'Household Has Tribal Persons', 'Cooking Range Usage Level', 'Duct Location', 'Geometry Stories Low Rise', 'Geometry Building Number Units SFA', 'Heating Setpoint Has Offset', 'PV System Size', 'Cooking Range', 'Ceiling Fan', 'Cooling Setpoint Offset Period', 'Clothes Washer', 'PV Orientation', 'HVAC Cooling Partial Space Conditioning', 'Infiltration', 'PUMA Metro Status', 'Misc Freezer', 'Corridor', 'Insulation Wall', 'Geometry Foundation Type', 'Misc Pool Pump', 'Tenure', 'Geometry Building Horizontal Location MF', 'Neighbors', 'Cooling Setpoint Offset Magnitude', 'HVAC Has Ducts', 'Misc Pool', 'Has PV', 'HVAC Heating Type', 'Windows', 'Income', 'Refrigerator Usage Level', 'Geometry Building Type RECS', 'Clothes Dryer', 'Heating Setpoint Offset Period', 'Cooling Setpoint Has Offset', 'Radiant Barrier', 'Geometry Building Horizontal Location SFA', 'Insulation Ceiling', 'Insulation Foundation Wall', 'Insulation Floor', 'Heating Setpoint Offset Magnitude', 'Geometry Wall Exterior Finish', 'Heating Setpoint', 'Cooling Setpoint', 'Roof Material', 'HVAC Heating Type And Fuel', 'Refrigerator', 'Geometry Building Level MF', 'Geometry Building Number Units MF', 'Vintage', 'HVAC Shared Efficiencies', 'Census Division RECS', 'Vacancy Status', 'HVAC Has Shared System', 'Heating Fuel'}
# iter: 2, known_cap_cols: {'PUMA', 'ASHRAE IECC Climate Zone 2004', 'Misc Gas Grill', 'Usage Level', 'Misc Well Pump', 'Bathroom Spot Vent Hour', 'Clothes Dryer Usage Level', 'Bedrooms', 'Orientation', 'Hot Water Fixtures', 'State', 'Clothes Washer Usage Level', 'Range Spot Vent Hour', 'Misc Gas Fireplace', 'County and PUMA', 'Misc Gas Lighting', 'County'}
# Adding field: Census Division
# Adding field: Refrigerator Usage Level
# Adding field: Cooking Range Usage Level
# Adding field: Census Division RECS
# Adding field: PUMA Metro Status
# Adding field: Location Region
# Adding field: Geometry Building Type ACS
# Adding field: Geometry Building Type RECS
# Adding field: Lighting
# iter: 3, needed_cap_cols: {'Federal Poverty Level', 'Geometry Stories', 'Misc Hot Tub Spa', 'Geometry Floor Area Bin', 'Vintage ACS', 'Geometry Story Bin', 'Duct Leakage and Insulation', 'Occupants', 'Geometry Attic Type', 'Geometry Wall Type', 'Misc Pool Heater', 'Insulation Roof', 'HVAC Cooling Type', 'Water Heater Fuel', 'Income RECS2015', 'HVAC Heating Efficiency', 'Clothes Washer Presence', 'Geometry Garage', 'Insulation Rim Joist', 'HVAC Cooling Efficiency', 'Insulation Slab', 'Geometry Floor Area', 'Income RECS2020', 'Geometry Building Type Height', 'Water Heater In Unit', 'Water Heater Efficiency', 'Misc Extra Refrigerator', 'Window Areas', 'Dishwasher', 'HVAC Has Zonal Electric Heating', 'Household Has Tribal Persons', 'Duct Location', 'Geometry Stories Low Rise', 'Geometry Building Number Units SFA', 'Heating Setpoint Has Offset', 'PV System Size', 'Cooking Range', 'Ceiling Fan', 'Cooling Setpoint Offset Period', 'Clothes Washer', 'PV Orientation', 'HVAC Cooling Partial Space Conditioning', 'Infiltration', 'Misc Freezer', 'Corridor', 'Insulation Wall', 'Geometry Foundation Type', 'Misc Pool Pump', 'Tenure', 'Geometry Building Horizontal Location MF', 'Neighbors', 'Cooling Setpoint Offset Magnitude', 'HVAC Has Ducts', 'Misc Pool', 'Has PV', 'HVAC Heating Type', 'Windows', 'Income', 'Clothes Dryer', 'Heating Setpoint Offset Period', 'Cooling Setpoint Has Offset', 'Radiant Barrier', 'Geometry Building Horizontal Location SFA', 'Insulation Ceiling', 'Insulation Foundation Wall', 'Insulation Floor', 'Heating Setpoint Offset Magnitude', 'Geometry Wall Exterior Finish', 'Heating Setpoint', 'Cooling Setpoint', 'Roof Material', 'HVAC Heating Type And Fuel', 'Refrigerator', 'Geometry Building Level MF', 'Geometry Building Number Units MF', 'Vintage', 'HVAC Shared Efficiencies', 'Vacancy Status', 'HVAC Has Shared System', 'Heating Fuel'}
# iter: 3, known_cap_cols: {'Census Division', 'ASHRAE IECC Climate Zone 2004', 'Clothes Dryer Usage Level', 'Clothes Washer Usage Level', 'Geometry Building Type ACS', 'PUMA', 'Orientation', 'Refrigerator Usage Level', 'Geometry Building Type RECS', 'Range Spot Vent Hour', 'County and PUMA', 'Misc Gas Lighting', 'County', 'Misc Gas Grill', 'Misc Well Pump', 'PUMA Metro Status', 'Misc Gas Fireplace', 'Location Region', 'Usage Level', 'Lighting', 'Bathroom Spot Vent Hour', 'Bedrooms', 'Hot Water Fixtures', 'State', 'Census Division RECS', 'Cooking Range Usage Level'}
# Adding field: Vintage
# Adding field: Geometry Building Number Units SFA
# Adding field: Radiant Barrier
# Adding field: Geometry Building Horizontal Location SFA
# Adding field: Neighbors
# Adding field: Cooling Setpoint Has Offset
# Adding field: Vintage ACS
# Adding field: Roof Material
# Adding field: Vacancy Status
# Adding field: Cooling Setpoint Offset Magnitude
# Adding field: Cooling Setpoint Offset Period
# Adding field: Tenure
# Adding field: Corridor
# Adding field: Heating Fuel
# Adding field: Geometry Foundation Type
# Adding field: Water Heater In Unit
# Adding field: Insulation Slab
# iter: 4, needed_cap_cols: {'Federal Poverty Level', 'Geometry Stories', 'Misc Hot Tub Spa', 'Geometry Floor Area Bin', 'Geometry Story Bin', 'Duct Leakage and Insulation', 'Occupants', 'Geometry Attic Type', 'Geometry Wall Type', 'Misc Pool Heater', 'Insulation Roof', 'HVAC Cooling Type', 'Water Heater Fuel', 'Income RECS2015', 'HVAC Heating Efficiency', 'Clothes Washer Presence', 'Geometry Garage', 'Insulation Rim Joist', 'HVAC Cooling Efficiency', 'Geometry Floor Area', 'Income RECS2020', 'Geometry Building Type Height', 'Water Heater Efficiency', 'Misc Extra Refrigerator', 'Window Areas', 'Dishwasher', 'HVAC Has Zonal Electric Heating', 'Household Has Tribal Persons', 'Duct Location', 'Geometry Stories Low Rise', 'Heating Setpoint Has Offset', 'PV System Size', 'Cooking Range', 'Ceiling Fan', 'Clothes Washer', 'PV Orientation', 'HVAC Cooling Partial Space Conditioning', 'Infiltration', 'Misc Freezer', 'Insulation Wall', 'Misc Pool Pump', 'Geometry Building Horizontal Location MF', 'HVAC Has Ducts', 'Misc Pool', 'Has PV', 'HVAC Heating Type', 'Windows', 'Income', 'Clothes Dryer', 'Heating Setpoint Offset Period', 'Insulation Ceiling', 'Insulation Foundation Wall', 'Insulation Floor', 'Heating Setpoint Offset Magnitude', 'Geometry Wall Exterior Finish', 'Heating Setpoint', 'Cooling Setpoint', 'HVAC Heating Type And Fuel', 'Refrigerator', 'Geometry Building Level MF', 'Geometry Building Number Units MF', 'HVAC Shared Efficiencies', 'HVAC Has Shared System'}
# iter: 4, known_cap_cols: {'Census Division', 'ASHRAE IECC Climate Zone 2004', 'Insulation Slab', 'Clothes Dryer Usage Level', 'Clothes Washer Usage Level', 'Geometry Building Number Units SFA', 'Geometry Building Type ACS', 'PUMA', 'Vintage ACS', 'Orientation', 'Refrigerator Usage Level', 'Water Heater In Unit', 'Geometry Building Type RECS', 'Range Spot Vent Hour', 'Cooling Setpoint Offset Period', 'County and PUMA', 'Misc Gas Lighting', 'County', 'Cooling Setpoint Has Offset', 'Misc Gas Grill', 'Radiant Barrier', 'Geometry Building Horizontal Location SFA', 'Misc Well Pump', 'PUMA Metro Status', 'Misc Gas Fireplace', 'Location Region', 'Vacancy Status', 'Corridor', 'Usage Level', 'Roof Material', 'Lighting', 'Bathroom Spot Vent Hour', 'Bedrooms', 'Geometry Foundation Type', 'Hot Water Fixtures', 'State', 'Vintage', 'Tenure', 'Cooling Setpoint Offset Magnitude', 'Census Division RECS', 'Neighbors', 'Cooking Range Usage Level', 'Heating Fuel'}
# Adding field: Ceiling Fan
# Adding field: Insulation Foundation Wall
# Adding field: HVAC Heating Type
# Adding field: Income
# Adding field: Has PV
# Adding field: Income RECS2015
# Adding field: Insulation Floor
# Adding field: Water Heater Fuel
# Adding field: HVAC Cooling Type
# Adding field: Income RECS2020
# Adding field: Insulation Rim Joist
# iter: 5, needed_cap_cols: {'Federal Poverty Level', 'Geometry Stories', 'Misc Hot Tub Spa', 'Geometry Floor Area Bin', 'Geometry Story Bin', 'Duct Leakage and Insulation', 'Occupants', 'Geometry Attic Type', 'Geometry Wall Type', 'Misc Pool Heater', 'Insulation Roof', 'HVAC Heating Efficiency', 'Clothes Washer Presence', 'Geometry Garage', 'HVAC Cooling Efficiency', 'Geometry Floor Area', 'Geometry Building Type Height', 'Water Heater Efficiency', 'Misc Extra Refrigerator', 'Window Areas', 'Dishwasher', 'HVAC Has Zonal Electric Heating', 'Household Has Tribal Persons', 'Duct Location', 'Geometry Stories Low Rise', 'Heating Setpoint Has Offset', 'PV System Size', 'Cooking Range', 'Clothes Washer', 'PV Orientation', 'HVAC Cooling Partial Space Conditioning', 'Infiltration', 'Misc Freezer', 'Insulation Wall', 'Misc Pool Pump', 'Geometry Building Horizontal Location MF', 'HVAC Has Ducts', 'Misc Pool', 'Windows', 'Clothes Dryer', 'Heating Setpoint Offset Period', 'Insulation Ceiling', 'Heating Setpoint Offset Magnitude', 'Geometry Wall Exterior Finish', 'Heating Setpoint', 'Cooling Setpoint', 'HVAC Heating Type And Fuel', 'Refrigerator', 'Geometry Building Level MF', 'Geometry Building Number Units MF', 'HVAC Shared Efficiencies', 'HVAC Has Shared System'}
# iter: 5, known_cap_cols: {'Census Division', 'ASHRAE IECC Climate Zone 2004', 'Insulation Rim Joist', 'Insulation Slab', 'Clothes Dryer Usage Level', 'Income RECS2020', 'Clothes Washer Usage Level', 'Geometry Building Number Units SFA', 'Geometry Building Type ACS', 'Has PV', 'PUMA', 'HVAC Heating Type', 'Vintage ACS', 'Income', 'Orientation', 'Refrigerator Usage Level', 'Water Heater In Unit', 'Geometry Building Type RECS', 'Range Spot Vent Hour', 'Ceiling Fan', 'Cooling Setpoint Offset Period', 'County and PUMA', 'Misc Gas Lighting', 'County', 'Cooling Setpoint Has Offset', 'Misc Gas Grill', 'Radiant Barrier', 'Geometry Building Horizontal Location SFA', 'Misc Well Pump', 'PUMA Metro Status', 'Misc Gas Fireplace', 'Insulation Foundation Wall', 'Insulation Floor', 'Location Region', 'Vacancy Status', 'Corridor', 'Usage Level', 'Roof Material', 'HVAC Cooling Type', 'Lighting', 'Water Heater Fuel', 'Bathroom Spot Vent Hour', 'Bedrooms', 'Geometry Foundation Type', 'Hot Water Fixtures', 'State', 'Vintage', 'Tenure', 'Cooling Setpoint Offset Magnitude', 'Income RECS2015', 'Census Division RECS', 'Neighbors', 'Cooking Range Usage Level', 'Heating Fuel'}
# Adding field: Water Heater Efficiency
# Adding field: PV System Size
# Adding field: HVAC Has Shared System
# Adding field: PV Orientation
# Adding field: HVAC Has Ducts
# Adding field: Occupants
# Adding field: Geometry Floor Area
# Adding field: Cooling Setpoint
# Adding field: Federal Poverty Level
# Adding field: Household Has Tribal Persons
# Adding field: HVAC Shared Efficiencies
# Adding field: Cooking Range
# Adding field: HVAC Heating Efficiency
# Adding field: Misc Extra Refrigerator
# Adding field: Dishwasher
# Adding field: Geometry Floor Area Bin
# Adding field: Clothes Washer Presence
# Adding field: Misc Hot Tub Spa
# Adding field: HVAC Has Zonal Electric Heating
# Adding field: Windows
# iter: 6, needed_cap_cols: {'Geometry Stories', 'Geometry Story Bin', 'Duct Leakage and Insulation', 'Geometry Attic Type', 'Geometry Wall Type', 'Misc Pool Heater', 'Insulation Roof', 'Geometry Garage', 'HVAC Cooling Efficiency', 'Geometry Building Type Height', 'Window Areas', 'Duct Location', 'Geometry Stories Low Rise', 'Heating Setpoint Has Offset', 'Clothes Washer', 'HVAC Cooling Partial Space Conditioning', 'Infiltration', 'Misc Freezer', 'Insulation Wall', 'Misc Pool Pump', 'Geometry Building Horizontal Location MF', 'Misc Pool', 'Clothes Dryer', 'Heating Setpoint Offset Period', 'Insulation Ceiling', 'Heating Setpoint Offset Magnitude', 'Geometry Wall Exterior Finish', 'Heating Setpoint', 'HVAC Heating Type And Fuel', 'Refrigerator', 'Geometry Building Level MF', 'Geometry Building Number Units MF'}
# iter: 6, known_cap_cols: {'Census Division', 'ASHRAE IECC Climate Zone 2004', 'Insulation Rim Joist', 'Insulation Slab', 'Geometry Floor Area', 'Clothes Dryer Usage Level', 'Income RECS2020', 'Federal Poverty Level', 'Clothes Washer Usage Level', 'Geometry Building Number Units SFA', 'Misc Hot Tub Spa', 'Geometry Building Type ACS', 'HVAC Has Ducts', 'PV System Size', 'Has PV', 'PUMA', 'HVAC Heating Type', 'Geometry Floor Area Bin', 'Vintage ACS', 'Windows', 'Cooking Range', 'Income', 'Orientation', 'Refrigerator Usage Level', 'Water Heater In Unit', 'Geometry Building Type RECS', 'Range Spot Vent Hour', 'Occupants', 'Ceiling Fan', 'Cooling Setpoint Offset Period', 'County and PUMA', 'Misc Gas Lighting', 'County', 'Cooling Setpoint Has Offset', 'Water Heater Efficiency', 'Misc Gas Grill', 'Radiant Barrier', 'Geometry Building Horizontal Location SFA', 'Misc Well Pump', 'PV Orientation', 'PUMA Metro Status', 'Misc Extra Refrigerator', 'Misc Gas Fireplace', 'Insulation Foundation Wall', 'Insulation Floor', 'Dishwasher', 'Location Region', 'Vacancy Status', 'Corridor', 'Usage Level', 'Roof Material', 'Cooling Setpoint', 'HVAC Has Zonal Electric Heating', 'HVAC Cooling Type', 'Lighting', 'Water Heater Fuel', 'Bathroom Spot Vent Hour', 'Bedrooms', 'Geometry Foundation Type', 'Hot Water Fixtures', 'State', 'Vintage', 'Tenure', 'Cooling Setpoint Offset Magnitude', 'Income RECS2015', 'Household Has Tribal Persons', 'Census Division RECS', 'HVAC Shared Efficiencies', 'HVAC Heating Efficiency', 'Clothes Washer Presence', 'Neighbors', 'Cooking Range Usage Level', 'HVAC Has Shared System', 'Heating Fuel'}
# Adding field: HVAC Cooling Partial Space Conditioning
# Adding field: Geometry Stories
# Adding field: Geometry Building Number Units MF
# Adding field: HVAC Cooling Efficiency
# Adding field: Misc Freezer
# Adding field: Geometry Story Bin
# Adding field: Infiltration
# Adding field: Geometry Stories Low Rise
# Adding field: Clothes Washer
# Adding field: Geometry Garage
# Adding field: Geometry Attic Type
# Adding field: Heating Setpoint
# Adding field: Insulation Ceiling
# Adding field: Misc Pool
# Adding field: Refrigerator
# Adding field: Geometry Wall Type
# Adding field: HVAC Heating Type And Fuel
# Adding field: Misc Pool Pump
# Adding field: Heating Setpoint Has Offset
# Adding field: Clothes Dryer
# Adding field: Geometry Wall Exterior Finish
# Adding field: Geometry Building Type Height
# Adding field: Geometry Building Horizontal Location MF
# Adding field: Geometry Building Level MF
# Adding field: Insulation Roof
# Adding field: Misc Pool Heater
# iter: 7, needed_cap_cols: {'Duct Leakage and Insulation', 'Window Areas', 'Duct Location', 'Insulation Wall', 'Heating Setpoint Offset Period', 'Heating Setpoint Offset Magnitude'}
# iter: 7, known_cap_cols: {'Clothes Dryer Usage Level', 'Federal Poverty Level', 'Geometry Stories', 'Misc Hot Tub Spa', 'Geometry Floor Area Bin', 'Vintage ACS', 'Geometry Story Bin', 'Occupants', 'Geometry Attic Type', 'Geometry Wall Type', 'Misc Well Pump', 'Misc Pool Heater', 'Insulation Roof', 'Usage Level', 'HVAC Cooling Type', 'Lighting', 'Water Heater Fuel', 'Income RECS2015', 'HVAC Heating Efficiency', 'Clothes Washer Presence', 'Geometry Garage', 'Census Division', 'ASHRAE IECC Climate Zone 2004', 'Insulation Rim Joist', 'HVAC Cooling Efficiency', 'Insulation Slab', 'Geometry Floor Area', 'Income RECS2020', 'Clothes Washer Usage Level', 'Geometry Building Type Height', 'Geometry Building Type ACS', 'Orientation', 'Water Heater In Unit', 'Range Spot Vent Hour', 'County and PUMA', 'Misc Gas Lighting', 'County', 'Water Heater Efficiency', 'Misc Extra Refrigerator', 'Dishwasher', 'Location Region', 'HVAC Has Zonal Electric Heating', 'State', 'Household Has Tribal Persons', 'Cooking Range Usage Level', 'Geometry Stories Low Rise', 'Geometry Building Number Units SFA', 'Heating Setpoint Has Offset', 'PV System Size', 'Cooking Range', 'Ceiling Fan', 'Cooling Setpoint Offset Period', 'Clothes Washer', 'Misc Gas Grill', 'PV Orientation', 'HVAC Cooling Partial Space Conditioning', 'PUMA Metro Status', 'Infiltration', 'Misc Gas Fireplace', 'Misc Freezer', 'Corridor', 'Bathroom Spot Vent Hour', 'Geometry Foundation Type', 'Misc Pool Pump', 'Tenure', 'Geometry Building Horizontal Location MF', 'Neighbors', 'Cooling Setpoint Offset Magnitude', 'HVAC Has Ducts', 'Misc Pool', 'Has PV', 'PUMA', 'HVAC Heating Type', 'Windows', 'Income', 'Refrigerator Usage Level', 'Geometry Building Type RECS', 'Clothes Dryer', 'Cooling Setpoint Has Offset', 'Radiant Barrier', 'Geometry Building Horizontal Location SFA', 'Insulation Ceiling', 'Insulation Foundation Wall', 'Insulation Floor', 'Geometry Wall Exterior Finish', 'Heating Setpoint', 'Roof Material', 'Cooling Setpoint', 'HVAC Heating Type And Fuel', 'Refrigerator', 'Geometry Building Level MF', 'Geometry Building Number Units MF', 'Bedrooms', 'Hot Water Fixtures', 'Vintage', 'Census Division RECS', 'HVAC Shared Efficiencies', 'Vacancy Status', 'HVAC Has Shared System', 'Heating Fuel'}
# Adding field: Insulation Wall
# Adding field: Heating Setpoint Offset Period
# Adding field: Heating Setpoint Offset Magnitude
# Adding field: Window Areas
# Adding field: Duct Location
# iter: 8, needed_cap_cols: {'Duct Leakage and Insulation'}
# iter: 8, known_cap_cols: {'Clothes Dryer Usage Level', 'Federal Poverty Level', 'Geometry Stories', 'Misc Hot Tub Spa', 'Geometry Floor Area Bin', 'Vintage ACS', 'Geometry Story Bin', 'Occupants', 'Geometry Attic Type', 'Geometry Wall Type', 'Misc Well Pump', 'Misc Pool Heater', 'Insulation Roof', 'Usage Level', 'HVAC Cooling Type', 'Lighting', 'Water Heater Fuel', 'Income RECS2015', 'HVAC Heating Efficiency', 'Clothes Washer Presence', 'Geometry Garage', 'Census Division', 'ASHRAE IECC Climate Zone 2004', 'Insulation Rim Joist', 'HVAC Cooling Efficiency', 'Insulation Slab', 'Geometry Floor Area', 'Income RECS2020', 'Clothes Washer Usage Level', 'Geometry Building Type Height', 'Geometry Building Type ACS', 'Orientation', 'Water Heater In Unit', 'Range Spot Vent Hour', 'County and PUMA', 'Misc Gas Lighting', 'County', 'Water Heater Efficiency', 'Misc Extra Refrigerator', 'Window Areas', 'Dishwasher', 'Location Region', 'HVAC Has Zonal Electric Heating', 'State', 'Household Has Tribal Persons', 'Cooking Range Usage Level', 'Duct Location', 'Geometry Stories Low Rise', 'Geometry Building Number Units SFA', 'Heating Setpoint Has Offset', 'PV System Size', 'Cooking Range', 'Ceiling Fan', 'Cooling Setpoint Offset Period', 'Clothes Washer', 'Misc Gas Grill', 'PV Orientation', 'HVAC Cooling Partial Space Conditioning', 'PUMA Metro Status', 'Infiltration', 'Misc Gas Fireplace', 'Misc Freezer', 'Corridor', 'Insulation Wall', 'Bathroom Spot Vent Hour', 'Geometry Foundation Type', 'Misc Pool Pump', 'Tenure', 'Geometry Building Horizontal Location MF', 'Neighbors', 'Cooling Setpoint Offset Magnitude', 'HVAC Has Ducts', 'Misc Pool', 'Has PV', 'PUMA', 'HVAC Heating Type', 'Windows', 'Income', 'Refrigerator Usage Level', 'Geometry Building Type RECS', 'Clothes Dryer', 'Heating Setpoint Offset Period', 'Cooling Setpoint Has Offset', 'Radiant Barrier', 'Geometry Building Horizontal Location SFA', 'Insulation Ceiling', 'Insulation Foundation Wall', 'Insulation Floor', 'Heating Setpoint Offset Magnitude', 'Geometry Wall Exterior Finish', 'Heating Setpoint', 'Roof Material', 'Cooling Setpoint', 'HVAC Heating Type And Fuel', 'Refrigerator', 'Geometry Building Level MF', 'Geometry Building Number Units MF', 'Bedrooms', 'Hot Water Fixtures', 'Vintage', 'Census Division RECS', 'HVAC Shared Efficiencies', 'Vacancy Status', 'HVAC Has Shared System', 'Heating Fuel'}
# Adding field: Duct Leakage and Insulation

# %%
dep_df = pd.read_csv('dependencies.csv')
dep_map = {}
for i, row in dep_df.iterrows():
    dep_map[row['CapitalCase']] = row['UnderscoreCase']
    with open("underscore_lookup.json", "w") as f:
        json.dump(dep_map, f)

# %%
import pandas as pd
import json

county_df = pd.read_csv('/home/casey/Repos/ResStock/resstock/project_national/housing_characteristics/County and PUMA.tsv', sep='\t')
county_dict = {}
for col in county_df:
    if not col.startswith('Option='):
        continue
    gisjoin_statepuma = col.split('Option=')[1]
    # print(county)
    # print(county_df[col].unique())
    gisjoin, statepuma = gisjoin_statepuma.split(',')[0], gisjoin_statepuma.split(',')[1]
    geoid = statepuma[2:4] + statepuma[5:]
    # matching_rows = county_df.loc[county_df[col] == 1]
    # print(matching_rows)
    # matching_gispuma = matching_rows['Dependency=County and PUMA'].values[0]
    # gisjoin = matching_gispuma.split(',')[0]
    # if statepuma in county_dict:
    #     raise ValueError(f'statepuma {statepuma} is a duplicate')
    print(statepuma)
    print(geoid)
    # When pumas can be in multiple counties - this will overwrite the previous key, and lookup to the last county and puma. However I think this is not a big deal - knowing puma is detail enough, otherwise user would have to enter in county as well
    county_dict[geoid] = gisjoin_statepuma

with open("geoid_lookup.json", "w") as f:
    json.dump(county_dict, f)
# Out:
#  G01002100
# 0102100
#  G01002600
# 0102600
#  G01002400
# 0102400
#  G01001700
# 0101700
#  G01000800
# 0100800
#  G01002400
# 0102400
#  G01002300
# 0102300
#  G01001100
# 0101100
#  G01001800
# 0101800
#  G01001000
# 0101000
#  G01001800
# 0101800
#  G01002200
# 0102200
#  G01002200
# 0102200
#  G01001000
# 0101000
#  G01001000
# 0101000
#  G01002300
# 0102300
#  G01000100
# 0100100
#  G01002200
# 0102200
#  G01001800
# 0101800
#  G01002300
# 0102300
#  G01002300
# 0102300
#  G01000700
# 0100700
#  G01002500
# 0102500
#  G01001700
# 0101700
#  G01000400
# 0100400
#  G01002100
# 0102100
#  G01002200
# 0102200
#  G01000900
# 0100900
#  G01001400
# 0101400
#  G01000100
# 0100100
#  G01002500
# 0102500
#  G01001700
# 0101700
#  G01001700
# 0101700
#  G01002500
# 0102500
#  G01002500
# 0102500
#  G01000400
# 0100400
#  G01001301
# 0101301
#  G01001302
# 0101302
#  G01001303
# 0101303
#  G01001304
# 0101304
#  G01001305
# 0101305
#  G01001400
# 0101400
#  G01000100
# 0100100
#  G01000600
# 0100600
#  G01001900
# 0101900
#  G01000200
# 0100200
#  G01002100
# 0102100
#  G01002400
# 0102400
#  G01000200
# 0100200
#  G01000301
# 0100301
#  G01000302
# 0100302
#  G01000500
# 0100500
#  G01001700
# 0101700
#  G01000100
# 0100100
#  G01001400
# 0101400
#  G01000500
# 0100500
#  G01002701
# 0102701
#  G01002702
# 0102702
#  G01002703
# 0102703
#  G01002200
# 0102200
#  G01002000
# 0102000
#  G01002100
# 0102100
#  G01000600
# 0100600
#  G01001700
# 0101700
#  G01001500
# 0101500
#  G01002400
# 0102400
#  G01001000
# 0101000
#  G01002400
# 0102400
#  G01000800
# 0100800
#  G01001200
# 0101200
#  G01001700
# 0101700
#  G01001000
# 0101000
#  G01001800
# 0101800
#  G01001500
# 0101500
#  G01001600
# 0101600
#  G01001400
# 0101400
#  G01002200
# 0102200
#  G01002200
# 0102200
#  G01000700
# 0100700
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000101
# 0200101
#  G02000102
# 0200102
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000300
# 0200300
#  G02000400
# 0200400
#  G02000300
# 0200300
#  G02000300
# 0200300
#  G02000400
# 0200400
#  G02000300
# 0200300
#  G02000200
# 0200200
#  G02000300
# 0200300
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000200
# 0200200
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000300
# 0200300
#  G02000300
# 0200300
#  G02000300
# 0200300
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G02000400
# 0200400
#  G04000300
# 0400300
#  G04000900
# 0400900
#  G04000400
# 0400400
#  G04000800
# 0400800
#  G04000800
# 0400800
#  G04000800
# 0400800
#  G04000600
# 0400600
#  G04000100
# 0400100
#  G04000101
# 0400101
#  G04000102
# 0400102
#  G04000103
# 0400103
#  G04000104
# 0400104
#  G04000105
# 0400105
#  G04000106
# 0400106
#  G04000107
# 0400107
#  G04000108
# 0400108
#  G04000109
# 0400109
#  G04000110
# 0400110
#  G04000111
# 0400111
#  G04000112
# 0400112
#  G04000113
# 0400113
#  G04000114
# 0400114
#  G04000115
# 0400115
#  G04000116
# 0400116
#  G04000117
# 0400117
#  G04000118
# 0400118
#  G04000119
# 0400119
#  G04000120
# 0400120
#  G04000121
# 0400121
#  G04000122
# 0400122
#  G04000123
# 0400123
#  G04000124
# 0400124
#  G04000125
# 0400125
#  G04000126
# 0400126
#  G04000127
# 0400127
#  G04000128
# 0400128
#  G04000129
# 0400129
#  G04000130
# 0400130
#  G04000131
# 0400131
#  G04000132
# 0400132
#  G04000133
# 0400133
#  G04000134
# 0400134
#  G04000600
# 0400600
#  G04000300
# 0400300
#  G04000201
# 0400201
#  G04000202
# 0400202
#  G04000203
# 0400203
#  G04000204
# 0400204
#  G04000205
# 0400205
#  G04000206
# 0400206
#  G04000207
# 0400207
#  G04000208
# 0400208
#  G04000209
# 0400209
#  G04000800
# 0400800
#  G04000803
# 0400803
#  G04000805
# 0400805
#  G04000807
# 0400807
#  G04000900
# 0400900
#  G04000500
# 0400500
#  G04000700
# 0400700
#  G05001700
# 0501700
#  G05001800
# 0501800
#  G05001800
# 0501800
#  G05000300
# 0500300
#  G05000100
# 0500100
#  G05000300
# 0500300
#  G05001800
# 0501800
#  G05001900
# 0501900
#  G05000300
# 0500300
#  G05001800
# 0501800
#  G05001600
# 0501600
#  G05000500
# 0500500
#  G05000400
# 0500400
#  G05001800
# 0501800
#  G05001900
# 0501900
#  G05001300
# 0501300
#  G05000500
# 0500500
#  G05000600
# 0500600
#  G05001400
# 0501400
#  G05000600
# 0500600
#  G05000700
# 0500700
#  G05001900
# 0501900
#  G05001800
# 0501800
#  G05001800
# 0501800
#  G05001100
# 0501100
#  G05001500
# 0501500
#  G05000400
# 0500400
#  G05001600
# 0501600
#  G05001700
# 0501700
#  G05000500
# 0500500
#  G05002000
# 0502000
#  G08000100
# 0800100
#  G08000801
# 0800801
#  G08000800
# 0800800
#  G08000800
# 0800800
#  G08000100
# 0800100
#  G08000600
# 0800600
#  G08001002
# 0801002
#  G08000812
# 0800812
#  G08000813
# 0800813
#  G08000814
# 0800814
#  G08000815
# 0800815
#  G08000816
# 0800816
#  G08000900
# 0800900
#  G08000821
# 0800821
#  G08000822
# 0800822
#  G08000823
# 0800823
#  G08000400
# 0800400
#  G08000100
# 0800100
#  G08000823
# 0800823
#  G08004101
# 0804101
#  G08004102
# 0804102
#  G08004103
# 0804103
#  G08004104
# 0804104
#  G08004105
# 0804105
#  G08004106
# 0804106
#  G08000600
# 0800600
#  G08000200
# 0800200
#  G08000801
# 0800801
#  G08000400
# 0800400
#  G08000900
# 0800900
#  G08000900
# 0800900
#  G08000600
# 0800600
#  G08000400
# 0800400
#  G08000801
# 0800801
#  G08000804
# 0800804
#  G08000805
# 0800805
#  G08000817
# 0800817
#  G08000818
# 0800818
#  G08000819
# 0800819
#  G08000820
# 0800820
#  G08000821
# 0800821
#  G08000100
# 0800100
#  G08000100
# 0800100
#  G08000600
# 0800600
#  G08000900
# 0800900
#  G08000102
# 0800102
#  G08000103
# 0800103
#  G08000800
# 0800800
#  G08000100
# 0800100
#  G08000100
# 0800100
#  G08001001
# 0801001
#  G08001002
# 0801002
#  G08000800
# 0800800
#  G08000200
# 0800200
#  G08000900
# 0800900
#  G08001002
# 0801002
#  G08000100
# 0800100
#  G08000800
# 0800800
#  G08001002
# 0801002
#  G08000600
# 0800600
#  G08000100
# 0800100
#  G08000400
# 0800400
#  G08000800
# 0800800
#  G08000600
# 0800600
#  G08000700
# 0800700
#  G08000800
# 0800800
#  G08000200
# 0800200
#  G08000800
# 0800800
#  G08000200
# 0800200
#  G08000800
# 0800800
#  G08000900
# 0800900
#  G08001002
# 0801002
#  G08000100
# 0800100
#  G08000400
# 0800400
#  G08004101
# 0804101
#  G08000100
# 0800100
#  G08000100
# 0800100
#  G08000300
# 0800300
#  G08000802
# 0800802
#  G08000824
# 0800824
#  G08000100
# 0800100
#  G09000100
# 0900100
#  G09000101
# 0900101
#  G09000102
# 0900102
#  G09000103
# 0900103
#  G09000104
# 0900104
#  G09000105
# 0900105
#  G09000300
# 0900300
#  G09000301
# 0900301
#  G09000302
# 0900302
#  G09000303
# 0900303
#  G09000304
# 0900304
#  G09000305
# 0900305
#  G09000306
# 0900306
#  G09000500
# 0900500
#  G09000700
# 0900700
#  G09000900
# 0900900
#  G09000901
# 0900901
#  G09000902
# 0900902
#  G09000903
# 0900903
#  G09000904
# 0900904
#  G09000905
# 0900905
#  G09000906
# 0900906
#  G09001100
# 0901100
#  G09001101
# 0901101
#  G09001300
# 0901300
#  G09001500
# 0901500
#  G10000200
# 1000200
#  G10000101
# 1000101
#  G10000102
# 1000102
#  G10000103
# 1000103
#  G10000104
# 1000104
#  G10000300
# 1000300
#  G11000101
# 1100101
#  G11000102
# 1100102
#  G11000103
# 1100103
#  G11000104
# 1100104
#  G11000105
# 1100105
#  G12000101
#  G20001200
# 2001200
#  G20000100
# 2000100
#  G20000900
# 2000900
#  G20001200
# 2001200
#  G20001100
# 2001100
#  G20001301
# 2001301
#  G20001200
# 2001200
#  G20001200
# 2001200
#  G20000802
# 2000802
#  G20000400
# 2000400
#  G20000200
# 2000200
#  G20000601
# 2000601
#  G20000602
# 2000602
#  G20000603
# 2000603
#  G20000604
# 2000604
#  G20001200
# 2001200
#  G20001100
# 2001100
#  G20001100
# 2001100
#  G20001500
# 2001500
#  G20000100
# 2000100
#  G20000400
# 2000400
#  G20000200
# 2000200
#  G20001400
# 2001400
#  G20000100
# 2000100
#  G20000900
# 2000900
#  G20001000
# 2001000
#  G20000900
# 2000900
#  G20000200
# 2000200
#  G20001200
# 2001200
#  G20001400
# 2001400
#  G20000200
# 2000200
#  G20001500
# 2001500
#  G20000900
# 2000900
#  G20001200
# 2001200
#  G20000200
# 2000200
#  G20001500
# 2001500
#  G20000100
# 2000100
#  G20000100
# 2000100
#  G20000802
# 2000802
#  G20000100
# 2000100
#  G20000200
# 2000200
#  G20001100
# 2001100
#  G20000100
# 2000100
#  G20000300
# 2000300
#  G20001100
# 2001100
#  G20000100
# 2000100
#  G20001000
# 2001000
#  G20000200
# 2000200
#  G20001000
# 2001000
#  G20000300
# 2000300
#  G20000100
# 2000100
#  G20001100
# 2001100
#  G20000100
# 2000100
#  G20000200
# 2000200
#  G20000100
# 2000100
#  G20001301
# 2001301
#  G20001302
# 2001302
#  G20001303
# 2001303
#  G20001304
# 2001304
#  G20001200
# 2001200
#  G20000801
# 2000801
#  G20000802
# 2000802
#  G20000100
# 2000100
#  G20000100
# 2000100
#  G20000100
# 2000100
#  G20001100
# 2001100
#  G20001200
# 2001200
#  G20001200
# 2001200
#  G20001100
# 2001100
#  G20000100
# 2000100
#  G20000100
# 2000100
#  G20000802
# 2000802
#  G20000100
# 2000100
#  G20000200
# 2000200
#  G20000100
# 2000100
#  G20000900
# 2000900
#  G20000900
# 2000900
#  G20000500
# 2000500
#  G21000600
# 2100600
#  G21000400
# 2100400
#  G21002000
# 2102000
#  G21000100
# 2100100
#  G21000400
# 2100400
#  G21002700
# 2102700
#  G21000900
# 2100900
#  G21002500
# 2102500
#  G21002300
# 2102300
#  G21002800
# 2102800
#  G21002100
# 2102100
#  G21002700
# 2102700
#  G21001000
# 2101000
#  G21001300
# 2101300
#  G21001600
# 2101600
#  G21000400
# 2100400
#  G21000200
# 2100200
#  G21000100
# 2100100
#  G21002600
# 2102600
#  G21000100
# 2100100
#  G21002600
# 2102600
#  G21002800
# 2102800
#  G21000600
# 2100600
#  G21000300
# 2100300
#  G21002300
# 2102300
#  G21000800
# 2100800
#  G21000600
# 2100600
#  G21000200
# 2100200
#  G21000600
# 2100600
#  G21001500
# 2101500
#  G21000400
# 2100400
#  G21002800
# 2102800
#  G21002200
# 2102200
#  G21001901
# 2101901
#  G21001902
# 2101902
#  G21002700
# 2102700
#  G21001100
# 2101100
#  G21002000
# 2102000
#  G21000100
# 2100100
#  G21002600
# 2102600
#  G21002100
# 2102100
#  G21002600
# 2102600
#  G21000100
# 2100100
#  G21001300
# 2101300
#  G21000600
# 2100600
#  G21002800
# 2102800
#  G21001500
# 2101500
#  G21001200
# 2101200
#  G21001300
# 2101300
#  G21000900
# 2100900
#  G21002300
# 2102300
#  G21000400
# 2100400
#  G21001400
# 2101400
#  G21001800
# 2101800
#  G21000100
# 2100100
#  G21000200
# 2100200
#  G21000800
# 2100800
#  G21001701
# 2101701
#  G21001702
# 2101702
#  G21001703
# 2101703
#  G21001704
# 2101704
#  G21001705
# 2101705
#  G21001706
# 2101706
#  G21002100
# 2102100
#  G21001100
# 2101100
#  G21002400
# 2102400
#  G21001000
# 2101000
#  G21000900
# 2100900
#  G21001200
# 2101200
#  G21000800
# 2100800
#  G21002800
# 2102800
#  G21001000
# 2101000
#  G21001000
# 2101000
#  G21001000
# 2101000
#  G21002700
# 2102700
#  G21002100
# 2102100
#  G21000200
# 2100200
#  G21000400
# 2100400
#  G21000300
# 2100300
#  G21000100
# 2100100
#  G21000700
# 2100700
#  G21001400
# 2101400
#  G21002200
# 2102200
#  G21001100
# 2101100
#  G21001200
# 2101200
#  G21000100
# 2100100
#  G21001100
# 2101100
#  G21002700
# 2102700
#  G21001300
# 2101300
#  G21002700
# 2102700
#  G21002000
# 2102000
#  G21000400
# 2100400
#  G21000400
# 2100400
#  G21002700
# 2102700
#  G21002700
# 2102700
#  G21000200
# 2100200
#  G21001200
# 2101200
#  G21002300
# 2102300
#  G21001400
# 2101400
#  G21001800
# 2101800
#  G21002600
# 2102600
#  G21001000
# 2101000
#  G21002600
# 2102600
#  G21001000
# 2101000
#  G21001100
# 2101100
#  G21002200
# 2102200
#  G21000700
# 2100700
#  G21002700
# 2102700
#  G21000800
# 2100800
#  G21002700
# 2102700
#  G21000600
# 2100600
#  G21002300
# 2102300
#  G21001600
# 2101600
#  G21001800
# 2101800
#  G21000400
# 2100400
#  G21001600
# 2101600
#  G21000600
# 2100600
#  G21000300
# 2100300
#  G21000300
# 2100300
#  G21001800
# 2101800
#  G21001400
# 2101400
#  G21000500
# 2100500
#  G21001200
# 2101200
#  G21000700
# 2100700
#  G21001400
# 2101400
#  G21000900
# 2100900
#  G21001000
# 2101000
#  G21002000
# 2102000
#  G22001100
# 2201100
#  G22000800
# 2200800
#  G22001600
# 2201600
#  G22002000
# 2202000
#  G22000600
# 2200600
#  G22000800
# 2200800
#  G22000300
# 2200300
#  G22000200
# 2200200
#  G22000100
# 2200100
#  G22000101
# 2200101
#  G22000800
# 2200800
#  G22000900
# 2200900
#  G22000500
# 2200500
#  G22000900
# 2200900
#  G22000600
# 2200600
#  G22000300
# 2200300
#  G22000600
# 2200600
#  G22000300
# 2200300
#  G22001500
# 2201500
#  G22001501
# 2201501
#  G22001502
# 2201502
#  G22000500
# 2200500
#  G22001400
# 2201400
#  G22001000
# 2201000
#  G22000500
# 2200500
#  G22000600
# 2200600
#  G22001300
# 2201300
#  G22001400
# 2201400
#  G22000500
# 2200500
#  G22002300
# 2202300
#  G22002301
# 2202301
#  G22002302
# 2202302
#  G22002500
# 2202500
#  G22000900
# 2200900
#  G22001200
# 2201200
#  G22001201
# 2201201
#  G22002000
# 2202000
#  G22000600
# 2200600
#  G22000300
# 2200300
#  G22001700
# 2201700
#  G22000500
# 2200500
#  G22000500
# 2200500
#  G22000300
# 2200300
#  G22002400
# 2202400
#  G22002401
# 2202401
#  G22002402
# 2202402
#  G22000400
# 2200400
#  G22002500
# 2202500
#  G22001400
# 2201400
#  G22000700
# 2200700
#  G22000300
# 2200300
#  G22000500
# 2200500
#  G22000300
# 2200300
#  G22002500
# 2202500
#  G22001900
# 2201900
#  G22001700
# 2201700
#  G22001900
# 2201900
#  G22001900
# 2201900
#  G22001000
# 2201000
#  G22001300
# 2201300
#  G22001300
# 2201300
#  G22002200
# 2202200
#  G22002201
# 2202201
#  G22001800
# 2201800
#  G22000500
# 2200500
#  G22002100
# 2202100
#  G22000500
# 2200500
#  G22001100
# 2201100
#  G22000700
# 2200700
#  G22001800
# 2201800
#  G22000200
# 2200200
#  G22001400
# 2201400
#  G22000500
# 2200500
#  G22001400
# 2201400
#  G22000600
# 2200600
#  G23000600
# 2300600
#  G23000100
# 2300100
#  G23000700
# 2300700
#  G23000800
# 2300800
#  G23000900
# 2300900
#  G23001000
# 2301000
#  G23000200
# 2300200
#  G23000500
# 2300500
#  G23000400
# 2300400
#  G23000500
# 2300500
#  G23000500
# 2300500
#  G23000200
# 2300200
#  G23000300
# 2300300
#  G23000200
# 2300200
#  G23000700
# 2300700
#  G23000200
# 2300200
#  G23000500
# 2300500
#  G23000100
# 2300100
#  G23000800
# 2300800
#  G23000900
# 2300900
#  G24000100
# 2400100
#  G24001201
# 2401201
#  G24001202
# 2401202
#  G24001203
# 2401203
#  G24001204
# 2401204
#  G24000501
# 2400501
#  G24000502
# 2400502
#  G24000503
# 2400503
#  G24000504
# 2400504
#  G24000505
# 2400505
#  G24000506
# 2400506
#  G24000507
# 2400507
#  G24001500
# 2401500
#  G24001300
# 2401300
#  G24000400
# 2400400
#  G24000700
# 2400700
#  G24001600
# 2401600
#  G24001300
# 2401300
#  G24000301
# 2400301
#  G24000302
# 2400302
#  G24000100
# 2400100
#  G24000601
# 2400601
#  G24000602
# 2400602
#  G24000901
# 2400901
#  G24000902
# 2400902
#  G24001300
# 2401300
#  G24001001
# 2401001
#  G24001002
# 2401002
#  G24001003
# 2401003
#  G24001004
# 2401004
#  G24001005
# 2401005
#  G24001006
# 2401006
#  G24001007
# 2401007
#  G24001101
# 2401101
#  G24001102
# 2401102
#  G24001103
# 2401103
#  G24001104
# 2401104
#  G24001105
# 2401105
#  G24001106
# 2401106
#  G24001107
# 2401107
#  G24001300
# 2401300
#  G24001500
# 2401500
#  G24001400
# 2401400
#  G24001300
# 2401300
#  G24000200
# 2400200
#  G24001400
# 2401400
#  G24001400
# 2401400
#  G24000801
# 2400801
#  G24000802
# 2400802
#  G24000803
# 2400803
#  G24000804
# 2400804
#  G24000805
# 2400805
#  G25004700
# 2504700
#  G25004800
# 2504800
#  G25000100
#  G29000700
# 2900700
#  G29000800
# 2900800
#  G29002400
# 2902400
#  G29002400
# 2902400
#  G29001701
# 2901701
#  G29001702
# 2901702
#  G29001703
# 2901703
#  G29001200
# 2901200
#  G29002100
# 2902100
#  G29002100
# 2902100
#  G29001801
# 2901801
#  G29001802
# 2901802
#  G29001803
# 2901803
#  G29001804
# 2901804
#  G29001805
# 2901805
#  G29001806
# 2901806
#  G29001807
# 2901807
#  G29001808
# 2901808
#  G29000700
# 2900700
#  G29000300
# 2900300
#  G29000300
# 2900300
#  G29002200
# 2902200
#  G29002500
# 2902500
#  G29000300
# 2900300
#  G29002300
# 2902300
#  G29002700
# 2902700
#  G29000100
# 2900100
#  G29002700
# 2902700
#  G29002500
# 2902500
#  G29001200
# 2901200
#  G29000400
# 2900400
#  G29002100
# 2902100
#  G29002400
# 2902400
#  G29002601
# 2902601
#  G29000100
# 2900100
#  G29002500
# 2902500
#  G29001901
# 2901901
#  G29001902
# 2901902
#  G30000300
# 3000300
#  G30000600
# 3000600
#  G30000400
# 3000400
#  G30000300
# 3000300
#  G30000500
# 3000500
#  G30000600
# 3000600
#  G30000400
# 3000400
#  G30000400
# 3000400
#  G30000600
# 3000600
#  G30000600
# 3000600
#  G30000600
# 3000600
#  G30000300
# 3000300
#  G30000600
# 3000600
#  G30000400
# 3000400
#  G30000100
# 3000100
#  G30000500
# 3000500
#  G30000600
# 3000600
#  G30000100
# 3000100
#  G30000600
# 3000600
#  G30000300
# 3000300
#  G30000400
# 3000400
#  G30000300
# 3000300
#  G30000400
# 3000400
#  G30000200
# 3000200
#  G30000300
# 3000300
#  G30000400
# 3000400
#  G30000100
# 3000100
#  G30000600
# 3000600
#  G30000300
# 3000300
#  G30000400
# 3000400
#  G30000200
# 3000200
#  G30000200
# 3000200
#  G30000600
# 3000600
#  G30000500
# 3000500
#  G30000400
# 3000400
#  G30000600
# 3000600
#  G30000400
# 3000400
#  G30000600
# 3000600
#  G30000300
# 3000300
#  G30000600
# 3000600
#  G30000200
# 3000200
#  G30000600
# 3000600
#  G30000600
# 3000600
#  G30000600
# 3000600
#  G30000200
# 3000200
#  G30000600
# 3000600
#  G30000300
# 3000300
#  G30000500
# 3000500
#  G30000500
# 3000500
#  G30000400
# 3000400
#  G30000400
# 3000400
#  G30000600
# 3000600
#  G30000600
# 3000600
#  G30000400
# 3000400
#  G30000600
# 3000600
#  G30000600
# 3000600
#  G30000700
# 3000700
#  G31000500
# 3100500
#  G31000200
# 3100200
#  G31000400
# 3100400
#  G31000100
# 3100100
#  G31000300
# 3100300
#  G31000200
# 3100200
#  G31000100
# 3100100
#  G31000100
# 3100100
#  G31000100
# 3100100
#  G31000500
# 3100500
#  G31000200
# 3100200
#  G31000600
# 3100600
#  G31000701
# 3100701
#  G31000200
# 3100200
#  G31000400
# 3100400
#  G31000100
# 3100100
#  G31000100
# 3100100
#  G31000500
# 3100500
#  G31000200
# 3100200
#  G31000200
# 3100200
#  G31000300
# 3100300
#  G31000200
# 3100200
#  G31000100
# 3100100
#  G31000400
# 3100400
#  G31000100
# 3100100
#  G31000200
# 3100200
#  G31000701
# 3100701
#  G31000901
# 3100901
#  G31000902
# 3100902
#  G31000903
# 3100903
#  G31000904
# 3100904
#  G31000400
# 3100400
#  G31000600
# 3100600
#  G31000500
# 3100500
#  G31000400
# 3100400
#  G31000400
# 3100400
#  G31000600
# 3100600
#  G31000100
# 3100100
#  G31000300
# 3100300
#  G31000400
# 3100400
#  G31000400
# 3100400
#  G31000300
# 3100300
#  G31000300
# 3100300
#  G31000300
# 3100300
#  G31000500
# 3100500
#  G31000400
# 3100400
#  G31000400
# 3100400
#  G31000100
# 3100100
#  G31000400
# 3100400
#  G31000300
# 3100300
#  G31000600
# 3100600
#  G31000600
# 3100600
#  G31000500
# 3100500
#  G31000400
# 3100400
#  G31000100
# 3100100
#  G31000100
# 3100100
#  G31000200
# 3100200
#  G31000801
# 3100801
#  G31000802
# 3100802
#  G31000400
# 3100400
#  G31000400
# 3100400
#  G31000300
# 3100300
#  G31000400
# 3100400
#  G31000200
# 3100200
#  G31000300
# 3100300
#  G31000100
# 3100100
#  G31000200
# 3100200
#  G31000600
# 3100600
#  G31000500
# 3100500
#  G31000600
# 3100600
#  G31000600
# 3100600
#  G31000400
# 3100400
#  G31000500
# 3100500
#  G31000200
# 3100200
#  G31000200
# 3100200
#  G31000600
# 3100600
#  G31000400
# 3100400
#  G31000600
# 3100600
#  G31000100
# 3100100
#  G31000600
# 3100600
#  G31000702
# 3100702
#  G31000701
# 3100701
#  G31000100
# 3100100
#  G31000600
# 3100600
#  G31000100
# 3100100
#  G31000300
# 3100300
#  G31000100
# 3100100
#  G31000200
# 3100200
#  G31000600
# 3100600
#  G31000400
# 3100400
#  G31000200
# 3100200
#  G31000300
# 3100300
#  G31000701
# 3100701
#  G31000200
# 3100200
#  G31000500
# 3100500
#  G31000300
# 3100300
#  G31000600
# 3100600
#  G32000300
# 3200300
#  G32000401
# 3200401
#  G32000402
# 3200402
# ...
#  G48000600
# 4800600
#  G48000100
# 4800100
#  G48006100
# 4806100
#  G48005000
# 4805000
#  G48000400
# 4800400
#  G48006100
# 4806100
#  G48005100
# 4805100
#  G48000600
# 4800600
#  G48006500
# 4806500
#  G48003501
# 4803501
#  G48003502
# 4803502
#  G48005901
# 4805901
#  G48005902
# 4805902
#  G48005903
# 4805903
#  G48005904
# 4805904
#  G48005905
# 4805905
#  G48005906
# 4805906
#  G48005907
# 4805907
#  G48005908
# 4805908
#  G48005909
# 4805909
#  G48005910
# 4805910
#  G48005911
# 4805911
#  G48005912
# 4805912
#  G48005913
# 4805913
#  G48005914
# 4805914
#  G48005915
# 4805915
#  G48005916
# 4805916
#  G48006000
# 4806000
#  G48002800
# 4802800
#  G48003700
# 4803700
#  G48001100
# 4801100
#  G48004801
# 4804801
#  G48004802
# 4804802
#  G48004803
# 4804803
#  G48003602
# 4803602
#  G48003200
# 4803200
#  G48000100
# 4800100
#  G48006900
# 4806900
#  G48002600
# 4802600
#  G48003601
# 4803601
#  G48003400
# 4803400
#  G48005100
#  G48001000
# 4801000
#  G48000400
# 4800400
#  G48004000
# 4804000
#  G48003700
# 4803700
#  G48004100
# 4804100
#  G48002600
# 4802600
#  G48006601
# 4806601
#  G48006602
# 4806602
#  G48006603
# 4806603
#  G48000100
# 4800100
#  G48000100
# 4800100
#  G48004200
# 4804200
#  G48002200
# 4802200
#  G48001700
# 4801700
#  G48002400
# 4802400
#  G48000100
# 4800100
#  G48003200
# 4803200
#  G48003900
# 4803900
#  G48000200
# 4800200
#  G48003200
# 4803200
#  G48001300
# 4801300
#  G48000300
# 4800300
#  G48002800
# 4802800
#  G48006200
# 4806200
#  G48001000
# 4801000
#  G48003200
# 4803200
#  G48006500
# 4806500
#  G48000100
# 4800100
#  G48003601
# 4803601
#  G48000900
# 4800900
#  G48002600
# 4802600
#  G48001700
# 4801700
#  G48004100
# 4804100
#  G48004100
# 4804100
#  G48003900
# 4803900
#  G48006500
# 4806500
#  G48003400
# 4803400
#  G48002800
# 4802800
#  G48002600
# 4802600
#  G48002600
# 4802600
#  G48004100
# 4804100
#  G48000100
# 4800100
#  G48001501
# 4801501
#  G48001502
# 4801502
#  G48002200
# 4802200
#  G48006400
# 4806400
#  G48002600
# 4802600
#  G48002800
# 4802800
#  G48002600
# 4802600
#  G48002800
# 4802800
#  G48000100
# 4800100
#  G48002501
# 4802501
#  G48002502
# 4802502
#  G48002503
# 4802503
#  G48002504
# 4802504
#  G48002505
# 4802505
#  G48002506
# 4802506
#  G48002507
# 4802507
#  G48002508
# 4802508
#  G48002509
# 4802509
#  G48002510
# 4802510
#  G48002511
# 4802511
#  G48002512
# 4802512
#  G48002513
# 4802513
#  G48002514
# 4802514
#  G48002515
# 4802515
#  G48002516
# 4802516
#  G48002700
# 4802700
#  G48003200
# 4803200
#  G48000400
# 4800400
#  G48002600
# 4802600
#  G48001000
# 4801000
#  G48002900
# 4802900
#  G48005301
# 4805301
#  G48005302
# 4805302
#  G48005303
# 4805303
#  G48005304
# 4805304
#  G48005305
# 4805305
#  G48005306
# 4805306
#  G48005307
# 4805307
#  G48005308
# 4805308
#  G48005309
# 4805309
#  G48003900
# 4803900
#  G48004100
# 4804100
#  G48001200
# 4801200
#  G48002800
# 4802800
#  G48006200
# 4806200
#  G48006200
# 4806200
#  G48001300
# 4801300
#  G48005600
# 4805600
#  G48003900
# 4803900
#  G48005000
# 4805000
#  G48003200
# 4803200
#  G48003601
# 4803601
#  G48006301
# 4806301
#  G48006302
# 4806302
#  G48005000
# 4805000
#  G48000100
# 4800100
#  G48000700
# 4800700
#  G48000600
# 4800600
#  G48006900
# 4806900
#  G48005201
# 4805201
#  G48005202
# 4805202
#  G48005203
# 4805203
#  G48005204
# 4805204
#  G48005500
# 4805500
#  G48003200
# 4803200
#  G48000600
# 4800600
#  G48001300
# 4801300
#  G48000400
# 4800400
#  G48000600
# 4800600
#  G48006400
# 4806400
#  G48006200
# 4806200
#  G49021001
# 4921001
#  G49003001
# 4903001
#  G49005001
# 4905001
#  G49013001
# 4913001
#  G49013001
# 4913001
#  G49011001
#  G53011610
# 5311610
#  G53011611
# 5311611
#  G53011612
# 5311612
#  G53011613
# 5311613
#  G53011614
# 5311614
#  G53011615
# 5311615
#  G53011616
# 5311616
#  G53011801
# 5311801
#  G53011802
# 5311802
#  G53010800
# 5310800
#  G53011000
# 5311000
#  G53011000
# 5311000
#  G53010600
# 5310600
#  G53011300
# 5311300
#  G53010400
# 5310400
#  G53011200
# 5311200
#  G53010400
# 5310400
#  G53011501
# 5311501
#  G53011502
# 5311502
#  G53011503
# 5311503
#  G53011504
# 5311504
#  G53011505
# 5311505
#  G53011506
# 5311506
#  G53011507
# 5311507
#  G53010200
# 5310200
#  G53010200
# 5310200
#  G53011000
# 5311000
#  G53011701
# 5311701
#  G53011702
# 5311702
#  G53011703
# 5311703
#  G53011704
# 5311704
#  G53011705
# 5311705
#  G53011706
# 5311706
#  G53010501
# 5310501
#  G53010502
# 5310502
#  G53010503
# 5310503
#  G53010504
# 5310504
#  G53010400
# 5310400
#  G53011401
# 5311401
#  G53011402
# 5311402
#  G53011200
# 5311200
#  G53010703
# 5310703
#  G53010100
# 5310100
#  G53010600
# 5310600
#  G53010901
# 5310901
#  G53010902
# 5310902
#  G54000500
# 5400500
#  G54000400
# 5400400
#  G54000900
# 5400900
#  G54000600
# 5400600
#  G54000100
# 5400100
#  G54000800
# 5400800
#  G54000600
# 5400600
#  G54001000
# 5401000
#  G54000200
# 5400200
#  G54001200
# 5401200
#  G54000600
# 5400600
#  G54000500
# 5400500
#  G54001100
# 5401100
#  G54000400
# 5400400
#  G54000100
# 5400100
#  G54000500
# 5400500
#  G54000200
# 5400200
#  G54000600
# 5400600
#  G54000400
# 5400400
#  G54001000
# 5401000
#  G54000500
# 5400500
#  G54000900
# 5400900
#  G54001300
# 5401300
#  G54001300
# 5401300
#  G54000200
# 5400200
#  G54000100
# 5400100
#  G54000800
# 5400800
#  G54001200
# 5401200
#  G54000400
# 5400400
#  G54001300
# 5401300
#  G54000300
# 5400300
#  G54001100
# 5401100
#  G54000400
# 5400400
#  G54001100
# 5401100
#  G54000100
# 5400100
#  G54000500
# 5400500
#  G54000700
# 5400700
#  G54001100
# 5401100
#  G54000300
# 5400300
#  G54000900
# 5400900
#  G54001200
# 5401200
#  G54000500
# 5400500
#  G54000600
# 5400600
#  G54000600
# 5400600
#  G54001100
# 5401100
#  G54000200
# 5400200
#  G54000500
# 5400500
#  G54000600
# 5400600
#  G54000500
# 5400500
#  G54000800
# 5400800
#  G54001100
# 5401100
#  G54000600
# 5400600
#  G54000700
# 5400700
#  G54000700
# 5400700
#  G54001300
# 5401300
#  G55001601
# 5501601
#  G55000100
# 5500100
#  G55055101
# 5555101
#  G55000100
# 5500100
#  G55000200
# 5500200
#  G55000300
# 5500300
#  G55000700
# 5500700
#  G55000100
# 5500100
#  G55001401
# 5501401
#  G55055101
# 5555101
#  G55055103
# 5555103
#  G55055101
# 5555101
#  G55001000
# 5501000
#  G55000700
# 5500700
#  G55000101
# 5500101
#  G55000102
# 5500102
#  G55000103
# 5500103
#  G55001001
# 5501001
#  G55001300
# 5501300
#  G55000100
# 5500100
#  G55055102
# 5555102
#  G55055103
# 5555103
#  G55001300
# 5501300
#  G55001401
# 5501401
#  G55000600
# 5500600
#  G55000800
# 5500800
#  G55000800
# 5500800
#  G55001400
# 5501400
#  G55000800
# 5500800
#  G55000100
# 5500100
#  G55000700
# 5500700
#  G55001001
# 5501001
#  G55001601
# 5501601
#  G55010000
# 5510000
#  G55001301
# 5501301
#  G55000900
# 5500900
#  G55000800
# 5500800
#  G55000600
# 5500600
#  G55000600
# 5500600
#  G55001301
# 5501301
#  G55001600
# 5501600
#  G55001300
# 5501300
#  G55001400
# 5501400
#  G55001400
# 5501400
#  G55040101
# 5540101
#  G55040301
# 5540301
#  G55040701
# 5540701
#  G55041001
# 5541001
#  G55041002
# 5541002
#  G55041003
# 5541003
#  G55041004
# 5541004
#  G55041005
# 5541005
#  G55000700
# 5500700
#  G55001300
# 5501300
#  G55000600
# 5500600
#  G55001500
# 5501500
#  G55020000
# 5520000
#  G55000700
# 5500700
#  G55000700
# 5500700
#  G55055101
# 5555101
#  G55001601
# 5501601
#  G55000100
# 5500100
#  G55030000
# 5530000
#  G55000800
# 5500800
#  G55002400
# 5502400
#  G55000100
# 5500100
#  G55055102
# 5555102
#  G55001000
# 5501000
#  G55000100
# 5500100
#  G55001400
# 5501400
#  G55002500
# 5502500
#  G55000100
# 5500100
#  G55000700
# 5500700
#  G55000700
# 5500700
#  G55000600
# 5500600
#  G55050000
# 5550000
#  G55000100
# 5500100
#  G55020000
# 5520000
#  G55070101
# 5570101
#  G55070201
# 5570201
#  G55070301
# 5570301
#  G55001400
# 5501400
#  G55001400
# 5501400
#  G55001501
# 5501501
#  G55001601
# 5501601
#  G56000300
# 5600300
#  G56000100
# 5600100
#  G56000200
# 5600200
#  G56000400
# 5600400
#  G56000400
# 5600400
#  G56000200
# 5600200
#  G56000500
# 5600500
#  G56000200
# 5600200
#  G56000500
# 5600500
#  G56000200
# 5600200
#  G56000300
# 5600300
#  G56000100
# 5600100
#  G56000400
# 5600400
#  G56000200
# 5600200
#  G56000100
# 5600100
#  G56000200
# 5600200
#  G56000100
# 5600100
#  G56000500
# 5600500
#  G56000500
# 5600500
#  G56000100
# 5600100
#  G56000500
# 5600500
#  G56000200
# 5600200
#  G56000200
# 5600200

# %%
df = pd.read_csv('/home/casey/Repos/ResStock/resstock/project_national/housing_characteristics/Geometry Building Horizontal Location SFA.tsv', sep='\t', keep_default_na=False)  
print(df['Dependency=Geometry Building Number Units SFA'].unique())
# Out:
# ['None' '2' '3' '4' '5' '6' '7' '8' '9' '10' '12' '15' '16' '20' '24' '30'
#  '36' '50' '60' '90' '144' '# Created by: manually created'
#  '# Description: Location of the single-family attached unit horizontally within the building (left, middle, right).'
#  '# Source: Calculated directly from other distributions']

# %%
import os
import pandas as pd

directory = '/home/casey/Documents/Graduate_School/Masters_Project/Data/housing_characteristics/2022_1'
new_directory = '/home/casey/Documents/Graduate_School/Masters_Project/API/appfiles/housing_characteristics/2022_1'
for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    if os.path.isfile(file_path):
        df = pd.read_csv(file_path, sep='\t', keep_default_na=False, dtype='str', engine='c')
        df = df[~df.iloc[:, 0].str.startswith('#', na=False)]
        new_filename = filename.split('.')[0] + '.parquet'
        df.to_parquet(os.path.join(new_directory, new_filename))

# %%
# For row in dependencies list:
# Check 
import json
import numpy as np
import polars as pl
import pandas as pd
import re


def to_underscore_case(s):
    # Replace '::' with '/'
    s = s.replace('::', '/')
    
    # Convert CamelCase to snake_case
    s = re.sub(r'([a-z\d])([A-Z])', r'\1_\2', s)
    s = re.sub(r'([A-Z]+)([A-Z][a-z])', r'\1_\2', s)
    
    # Replace '-' and ' ' with '_'
    s = s.replace('-', '_').replace(' ', '_')
    
    # Convert to lowercase
    s = s.lower()
    
    return "in." + s

# Feats is dictionary with unserscore case field names, and value as value

def generate_sample(feats={'in.county':'G1200090'}, num_samples=100):
# For each row in dependencies list - check if we have what we need for this column, and if we need it. If so, add a column to the samples df, each of correct distribution according to the existing row
    
    if not "in.county" in feats:
        raise ValueError("feats must include at least in.county as a key")
    
    with open('resstock_county_lookup.json') as json_file:
        gispuma_lookup = json.load(json_file)

    gispuma = gispuma_lookup[feats["in.county"]]
    del feats["in.county"]
    feats["in.county_and_puma"] = gispuma
    dep_df = pd.read_csv('dependencies.csv')
    column_plan_df = pd.read_csv('column_plan.csv', usecols=['field_name','keep_for_model'])
    # List of columns that the model requires as inputs
    needed_und_cols = column_plan_df.loc[
        (column_plan_df['keep_for_model'] == 'Yes') | 
        (column_plan_df['keep_for_model'] == 'Split')
    ]['field_name'].to_list()
    needed_und_cols.append("in.county_and_puma")
    # Initialize with known parameters
    sample_df_dict = {'bldg_id': list(range(num_samples))}
    for key in feats:
        sample_df_dict[key] = [feats[key]]*num_samples
        needed_und_cols.remove(key)
    
    sample_df = pl.DataFrame(sample_df_dict)
    known_cap_cols  = set(dep_df[dep_df['UnderscoreCase'].isin(feats.keys())]['CapitalCase'].to_list())
    needed_cap_cols = set(dep_df[dep_df['UnderscoreCase'].isin(needed_und_cols)]['CapitalCase'].to_list())
    iter = 0
    while needed_cap_cols:
        iter += 1
        # print(f'iter: {iter}, needed_cap_cols: {needed_cap_cols}')
        # print(f'iter: {iter}, known_cap_cols: {known_cap_cols}')
        for i, field in dep_df['CapitalCase'].items():
            if field not in needed_cap_cols or field in known_cap_cols:
                continue
            dep_str = dep_df.loc[i, 'Dependencies']
            # print(dep_str)
            if pd.isnull(dep_str):
                dependencies = []
            else:
                dependencies = dep_str.split('|')
            
            if any(x not in known_cap_cols for x in dependencies):
                # Set difference - only add dependencies not already known
                needed_cap_cols.update(set(dependencies) - known_cap_cols)
                continue
            else: #All dependencies are already in sample_df
                sample_df = add_col_to_sample(sample_df, field, dependencies, num_samples)
                needed_cap_cols.remove(field)
                known_cap_cols.add(field)
        if iter > 500:
            break
    # Can safely remove all columns not needed for model but for dependencies
    model_cols = needed_und_cols + list(feats)
    model_cols.remove("in.county_and_puma")
    clean_sample(sample_df, model_cols).write_csv('sample_test.csv')

def clean_sample(sample_df: pl.DataFrame, model_cols:list[str]) -> pl.DataFrame:
    cleaned_df = (sample_df
        .lazy()
        # In.state is in.county before comma
        .drop("in.county")
        .with_columns(
            pl.col("in.county_and_puma").str.split(by=", ").list.first().alias("in.county")
        )
        .select(model_cols)
    )
    
    return cleaned_df.collect()


def add_col_to_sample(sample_df: pl.DataFrame, cap_field: str, cap_dependencies: list[str], num_points: int):
    directory = '/home/casey/Documents/Graduate_School/Masters_Project/API/appfiles/housing_characteristics'
    char_df = pl.scan_parquet(directory + '/' + cap_field + '.parquet')
    options = [col.split('Option=')[1] for col in char_df.columns if col.startswith('Option=')]

    # Easy case where there are no dependencies - only top row of char_df matters
    if not cap_dependencies:
        probs = (char_df
            .lazy()
            .select(pl.selectors.starts_with('Option='))
            .cast(pl.Float32)
            .collect()
            .to_numpy()
        )[0]
        probs /= np.sum(probs)
        samples = np.random.choice(options, p=probs, size=num_points,replace=True).tolist()
        sample_df = sample_df.with_columns(pl.Series(samples).alias(to_underscore_case(cap_field)))
        return sample_df
    
    und_dependencies = [to_underscore_case(d) for d in cap_dependencies]
    
    # Use later to join on
    sample_df_with_deps = (sample_df
        .lazy()
        .with_columns(deps_str=pl.concat_str(und_dependencies, separator="|"))
    )

    sample_col = (sample_df
        .lazy()
        # Will join back up with rest of sample later - only care about what impacts the new column for now
        .select(und_dependencies)
        # Do join on the first dependency (there is guaranteed to be at least one)
        .join(char_df, how='left', left_on=to_underscore_case(cap_dependencies[0]), right_on='Dependency=' + cap_dependencies[0], coalesce=False)
        # Further filter on all remaining dependencies - ideally would have joined on all dependencies but not implemented in polars. Equivalent to cross product and filter by multiple columns.
        .filter(
            # Pl.col(d) is the sample_df column, "Dependency=" is the char_df column" - all dependencies must match exactly
            pl.all_horizontal(
                pl.col(to_underscore_case(d)) == pl.col('Dependency=' + d) for d in cap_dependencies
            )
        )
        .cast({pl.selectors.starts_with('Option='): pl.Float64})
        .with_columns(probs_list=pl.concat_list(pl.selectors.starts_with('Option=')))
        # Normalize probabilities to sum to 1
        .with_columns(pl.col('probs_list').list.eval(pl.element() / pl.element().sum()))
        # Needs to be string rather than list becuase will be joining on it
        .with_columns(deps_str=pl.concat_str(pl.selectors.starts_with('Dependency='), separator="|"))
        # Grouping before calling numpy.random.choice to take advantage of vectorized version of the function - only calling it the minimum number of times, once per unique combo of dependencies
        .group_by("deps_str", "probs_list").len(name='count')
        .with_columns(
            (
                # Ideally this would be map batches for peformance but could not get it to work
                pl.struct(['probs_list', 'count']).map_elements(
                    lambda x: list(np.random.choice(options, p=np.array(x['probs_list'], dtype=float), size=x['count'],replace=True))
                    ,return_dtype=pl.List(pl.String)
                )
            ).alias('choices')
        )
        # Join back up with unique samples df version where dependencies match, so we now have a list of choices at each sample(row)
        .join(sample_df_with_deps, how='inner', on="deps_str", suffix="_sample", coalesce=True)
        # Create an index list column where there are several runs of 0-number of occurences of that dep combo, restarting for each group. Goal is to choose one of every option generated
        .with_columns(options_idx=pl.int_range(pl.len()).over("deps_str"))
        .with_columns(sample=pl.col("choices").list.get(pl.col("options_idx")))
        .rename({'sample': to_underscore_case(cap_field)})
        .drop('probs_list', 'deps_str', 'count', 'choices', 'options_idx')
    )

    return sample_col.collect()
generate_sample(num_samples=1000)
# Out:
# iter: 1, needed_cap_cols: {'Clothes Washer Usage Level', 'Dishwasher', 'Heating Setpoint Has Offset', 'Clothes Dryer', 'Misc Extra Refrigerator', 'Misc Gas Grill', 'Geometry Garage', 'Clothes Washer Presence', 'State', 'Occupants', 'Clothes Dryer Usage Level', 'Geometry Building Type ACS', 'HVAC Cooling Efficiency', 'Refrigerator', 'Tenure', 'HVAC Has Ducts', 'Has PV', 'PV System Size', 'Water Heater Fuel', 'Misc Pool Pump', 'Geometry Wall Exterior Finish', 'Geometry Stories Low Rise', 'Bathroom Spot Vent Hour', 'Misc Gas Lighting', 'Geometry Foundation Type', 'Cooling Setpoint Has Offset', 'Cooling Setpoint', 'Misc Hot Tub Spa', 'Usage Level', 'Water Heater In Unit', 'HVAC Has Zonal Electric Heating', 'Geometry Stories', 'Infiltration', 'Insulation Rim Joist', 'HVAC Cooling Type', 'Neighbors', 'Water Heater Efficiency', 'Roof Material', 'Insulation Ceiling', 'Radiant Barrier', 'Cooking Range', 'Household Has Tribal Persons', 'Window Areas', 'Geometry Building Number Units SFA', 'Refrigerator Usage Level', 'Clothes Washer', 'Geometry Attic Type', 'Heating Setpoint Offset Magnitude', 'Misc Pool Heater', 'Duct Location', 'Vintage', 'HVAC Shared Efficiencies', 'HVAC Cooling Partial Space Conditioning', 'Cooking Range Usage Level', 'Geometry Wall Type', 'HVAC Has Shared System', 'Geometry Building Horizontal Location MF', 'Cooling Setpoint Offset Magnitude', 'Duct Leakage and Insulation', 'Geometry Building Horizontal Location SFA', 'Ceiling Fan', 'County', 'HVAC Heating Type', 'Heating Setpoint Offset Period', 'Geometry Building Type Height', 'HVAC Heating Type And Fuel', 'Cooling Setpoint Offset Period', 'HVAC Heating Efficiency', 'Geometry Building Number Units MF', 'Insulation Slab', 'Lighting', 'Windows', 'Vacancy Status', 'Heating Setpoint', 'Geometry Building Level MF', 'Hot Water Fixtures', 'Misc Pool', 'Insulation Floor', 'Heating Fuel', 'Misc Gas Fireplace', 'Insulation Roof', 'Corridor', 'Misc Freezer', 'Range Spot Vent Hour', 'Orientation', 'Misc Well Pump', 'Geometry Floor Area', 'Bedrooms', 'Insulation Foundation Wall', 'Insulation Wall', 'PV Orientation'}
# iter: 1, known_cap_cols: {'County and PUMA'}
# iter: 2, needed_cap_cols: {'Dishwasher', 'Heating Setpoint Has Offset', 'Clothes Dryer', 'Misc Extra Refrigerator', 'Geometry Garage', 'Clothes Washer Presence', 'Occupants', 'Geometry Building Type ACS', 'Geometry Floor Area Bin', 'HVAC Cooling Efficiency', 'Income RECS2020', 'Vintage ACS', 'Geometry Building Type RECS', 'Refrigerator', 'Tenure', 'HVAC Has Ducts', 'Has PV', 'PV System Size', 'Water Heater Fuel', 'Misc Pool Pump', 'Geometry Wall Exterior Finish', 'Geometry Stories Low Rise', 'Geometry Foundation Type', 'Cooling Setpoint Has Offset', 'Cooling Setpoint', 'Misc Hot Tub Spa', 'Water Heater In Unit', 'Federal Poverty Level', 'HVAC Has Zonal Electric Heating', 'Income', 'Geometry Stories', 'Infiltration', 'Income RECS2015', 'Insulation Rim Joist', 'HVAC Cooling Type', 'Neighbors', 'Water Heater Efficiency', 'Roof Material', 'Insulation Ceiling', 'Radiant Barrier', 'Cooking Range', 'Household Has Tribal Persons', 'PUMA Metro Status', 'Census Division', 'Window Areas', 'Geometry Building Number Units SFA', 'Refrigerator Usage Level', 'Clothes Washer', 'Geometry Attic Type', 'Heating Setpoint Offset Magnitude', 'Misc Pool Heater', 'Duct Location', 'Vintage', 'HVAC Shared Efficiencies', 'HVAC Cooling Partial Space Conditioning', 'Cooking Range Usage Level', 'Geometry Wall Type', 'HVAC Has Shared System', 'Geometry Building Horizontal Location MF', 'Cooling Setpoint Offset Magnitude', 'Duct Leakage and Insulation', 'Geometry Building Horizontal Location SFA', 'Ceiling Fan', 'HVAC Heating Type', 'Heating Setpoint Offset Period', 'Geometry Building Type Height', 'HVAC Heating Type And Fuel', 'Cooling Setpoint Offset Period', 'HVAC Heating Efficiency', 'Geometry Building Number Units MF', 'Geometry Story Bin', 'Insulation Slab', 'Lighting', 'Windows', 'Vacancy Status', 'Heating Setpoint', 'Geometry Building Level MF', 'Census Division RECS', 'Misc Pool', 'Insulation Floor', 'Location Region', 'Heating Fuel', 'Insulation Roof', 'Corridor', 'Misc Freezer', 'Geometry Floor Area', 'Bedrooms', 'Insulation Foundation Wall', 'Insulation Wall', 'PV Orientation'}
# iter: 2, known_cap_cols: {'Misc Gas Grill', 'Clothes Washer Usage Level', 'County', 'Range Spot Vent Hour', 'Orientation', 'State', 'Usage Level', 'Bathroom Spot Vent Hour', 'Clothes Dryer Usage Level', 'PUMA', 'Misc Gas Lighting', 'County and PUMA', 'Hot Water Fixtures', 'Misc Gas Fireplace', 'ASHRAE IECC Climate Zone 2004', 'Misc Well Pump'}
# iter: 3, needed_cap_cols: {'Dishwasher', 'Heating Setpoint Has Offset', 'Clothes Dryer', 'Misc Extra Refrigerator', 'Geometry Garage', 'Clothes Washer Presence', 'Occupants', 'Geometry Floor Area Bin', 'HVAC Cooling Efficiency', 'Income RECS2020', 'Vintage ACS', 'Refrigerator', 'Tenure', 'HVAC Has Ducts', 'Has PV', 'PV System Size', 'Water Heater Fuel', 'Misc Pool Pump', 'Geometry Wall Exterior Finish', 'Geometry Stories Low Rise', 'Geometry Foundation Type', 'Cooling Setpoint Has Offset', 'Cooling Setpoint', 'Misc Hot Tub Spa', 'Water Heater In Unit', 'Federal Poverty Level', 'HVAC Has Zonal Electric Heating', 'Income', 'Geometry Stories', 'Infiltration', 'Income RECS2015', 'Insulation Rim Joist', 'HVAC Cooling Type', 'Neighbors', 'Water Heater Efficiency', 'Roof Material', 'Insulation Ceiling', 'Radiant Barrier', 'Cooking Range', 'Household Has Tribal Persons', 'Window Areas', 'Geometry Building Number Units SFA', 'Clothes Washer', 'Geometry Attic Type', 'Heating Setpoint Offset Magnitude', 'Misc Pool Heater', 'Duct Location', 'Vintage', 'HVAC Shared Efficiencies', 'HVAC Cooling Partial Space Conditioning', 'Geometry Wall Type', 'HVAC Has Shared System', 'Geometry Building Horizontal Location MF', 'Cooling Setpoint Offset Magnitude', 'Duct Leakage and Insulation', 'Geometry Building Horizontal Location SFA', 'Ceiling Fan', 'HVAC Heating Type', 'Heating Setpoint Offset Period', 'Geometry Building Type Height', 'HVAC Heating Type And Fuel', 'Cooling Setpoint Offset Period', 'HVAC Heating Efficiency', 'Geometry Building Number Units MF', 'Geometry Story Bin', 'Insulation Slab', 'Windows', 'Vacancy Status', 'Heating Setpoint', 'Geometry Building Level MF', 'Misc Pool', 'Insulation Floor', 'Heating Fuel', 'Insulation Roof', 'Corridor', 'Misc Freezer', 'Geometry Floor Area', 'Bedrooms', 'Insulation Foundation Wall', 'Insulation Wall', 'PV Orientation'}
# iter: 3, known_cap_cols: {'Clothes Washer Usage Level', 'Census Division RECS', 'Usage Level', 'Cooking Range Usage Level', 'Hot Water Fixtures', 'Misc Gas Grill', 'County', 'Location Region', 'State', 'Clothes Dryer Usage Level', 'County and PUMA', 'Geometry Building Type ACS', 'Misc Gas Fireplace', 'ASHRAE IECC Climate Zone 2004', 'Geometry Building Type RECS', 'Range Spot Vent Hour', 'Orientation', 'PUMA Metro Status', 'Misc Well Pump', 'Census Division', 'Lighting', 'Bathroom Spot Vent Hour', 'Refrigerator Usage Level', 'PUMA', 'Misc Gas Lighting'}
# iter: 4, needed_cap_cols: {'Dishwasher', 'Heating Setpoint Has Offset', 'Clothes Dryer', 'Misc Extra Refrigerator', 'Geometry Garage', 'Clothes Washer Presence', 'Occupants', 'Geometry Floor Area Bin', 'HVAC Cooling Efficiency', 'Income RECS2020', 'Refrigerator', 'HVAC Has Ducts', 'Has PV', 'PV System Size', 'Water Heater Fuel', 'Misc Pool Pump', 'Geometry Wall Exterior Finish', 'Geometry Stories Low Rise', 'Cooling Setpoint', 'Misc Hot Tub Spa', 'Federal Poverty Level', 'HVAC Has Zonal Electric Heating', 'Income', 'Geometry Stories', 'Infiltration', 'Income RECS2015', 'Insulation Rim Joist', 'HVAC Cooling Type', 'Water Heater Efficiency', 'Insulation Ceiling', 'Cooking Range', 'Household Has Tribal Persons', 'Window Areas', 'Clothes Washer', 'Geometry Attic Type', 'Heating Setpoint Offset Magnitude', 'Misc Pool Heater', 'Duct Location', 'HVAC Shared Efficiencies', 'HVAC Cooling Partial Space Conditioning', 'Geometry Wall Type', 'HVAC Has Shared System', 'Geometry Building Horizontal Location MF', 'Duct Leakage and Insulation', 'Ceiling Fan', 'HVAC Heating Type', 'Heating Setpoint Offset Period', 'Geometry Building Type Height', 'HVAC Heating Type And Fuel', 'HVAC Heating Efficiency', 'Geometry Building Number Units MF', 'Geometry Story Bin', 'Windows', 'Heating Setpoint', 'Geometry Building Level MF', 'Misc Pool', 'Insulation Floor', 'Insulation Roof', 'Misc Freezer', 'Geometry Floor Area', 'Bedrooms', 'Insulation Foundation Wall', 'Insulation Wall', 'PV Orientation'}
# iter: 4, known_cap_cols: {'Clothes Washer Usage Level', 'Cooling Setpoint Has Offset', 'Census Division RECS', 'Vintage', 'Usage Level', 'Cooking Range Usage Level', 'Water Heater In Unit', 'Hot Water Fixtures', 'Cooling Setpoint Offset Magnitude', 'Geometry Building Horizontal Location SFA', 'Misc Gas Grill', 'County', 'Location Region', 'State', 'Clothes Dryer Usage Level', 'Heating Fuel', 'County and PUMA', 'Geometry Building Type ACS', 'Misc Gas Fireplace', 'ASHRAE IECC Climate Zone 2004', 'Neighbors', 'Roof Material', 'Radiant Barrier', 'Vintage ACS', 'Geometry Building Type RECS', 'Tenure', 'Range Spot Vent Hour', 'Orientation', 'Corridor', 'Cooling Setpoint Offset Period', 'PUMA Metro Status', 'Misc Well Pump', 'Census Division', 'Insulation Slab', 'Lighting', 'Geometry Building Number Units SFA', 'Bathroom Spot Vent Hour', 'Refrigerator Usage Level', 'Vacancy Status', 'PUMA', 'Misc Gas Lighting', 'Geometry Foundation Type'}
# iter: 5, needed_cap_cols: {'Dishwasher', 'Heating Setpoint Has Offset', 'Clothes Dryer', 'Misc Extra Refrigerator', 'Geometry Garage', 'Clothes Washer Presence', 'Occupants', 'Geometry Floor Area Bin', 'HVAC Cooling Efficiency', 'Refrigerator', 'HVAC Has Ducts', 'PV System Size', 'Misc Pool Pump', 'Geometry Wall Exterior Finish', 'Geometry Stories Low Rise', 'Cooling Setpoint', 'Misc Hot Tub Spa', 'Federal Poverty Level', 'HVAC Has Zonal Electric Heating', 'Geometry Stories', 'Infiltration', 'Water Heater Efficiency', 'Insulation Ceiling', 'Cooking Range', 'Household Has Tribal Persons', 'Window Areas', 'Clothes Washer', 'Geometry Attic Type', 'Heating Setpoint Offset Magnitude', 'Misc Pool Heater', 'Duct Location', 'HVAC Shared Efficiencies', 'HVAC Cooling Partial Space Conditioning', 'Geometry Wall Type', 'HVAC Has Shared System', 'Geometry Building Horizontal Location MF', 'Duct Leakage and Insulation', 'Heating Setpoint Offset Period', 'Geometry Building Type Height', 'HVAC Heating Type And Fuel', 'HVAC Heating Efficiency', 'Geometry Building Number Units MF', 'Geometry Story Bin', 'Windows', 'Heating Setpoint', 'Geometry Building Level MF', 'Misc Pool', 'Insulation Roof', 'Misc Freezer', 'Geometry Floor Area', 'Bedrooms', 'Insulation Wall', 'PV Orientation'}
# iter: 5, known_cap_cols: {'Clothes Washer Usage Level', 'Cooling Setpoint Has Offset', 'Census Division RECS', 'Vintage', 'Usage Level', 'Cooking Range Usage Level', 'Water Heater In Unit', 'Hot Water Fixtures', 'Cooling Setpoint Offset Magnitude', 'Geometry Building Horizontal Location SFA', 'Ceiling Fan', 'Misc Gas Grill', 'County', 'Income', 'Location Region', 'Income RECS2015', 'State', 'Insulation Floor', 'Clothes Dryer Usage Level', 'Heating Fuel', 'County and PUMA', 'HVAC Cooling Type', 'Geometry Building Type ACS', 'Insulation Rim Joist', 'Misc Gas Fireplace', 'ASHRAE IECC Climate Zone 2004', 'Neighbors', 'Roof Material', 'Radiant Barrier', 'Income RECS2020', 'Vintage ACS', 'Geometry Building Type RECS', 'HVAC Heating Type', 'Tenure', 'Range Spot Vent Hour', 'Orientation', 'Corridor', 'Has PV', 'Cooling Setpoint Offset Period', 'PUMA Metro Status', 'Water Heater Fuel', 'Misc Well Pump', 'Census Division', 'Insulation Slab', 'Lighting', 'Insulation Foundation Wall', 'Geometry Building Number Units SFA', 'Bathroom Spot Vent Hour', 'Refrigerator Usage Level', 'Vacancy Status', 'PUMA', 'Misc Gas Lighting', 'Geometry Foundation Type'}
# iter: 6, needed_cap_cols: {'Dishwasher', 'Heating Setpoint Has Offset', 'Clothes Dryer', 'Misc Extra Refrigerator', 'Geometry Garage', 'Clothes Washer Presence', 'Occupants', 'HVAC Cooling Efficiency', 'Refrigerator', 'Misc Pool Pump', 'Geometry Wall Exterior Finish', 'Geometry Stories Low Rise', 'Misc Hot Tub Spa', 'Federal Poverty Level', 'Geometry Stories', 'Infiltration', 'Insulation Ceiling', 'Cooking Range', 'Household Has Tribal Persons', 'Window Areas', 'Clothes Washer', 'Geometry Attic Type', 'Heating Setpoint Offset Magnitude', 'Misc Pool Heater', 'Duct Location', 'HVAC Cooling Partial Space Conditioning', 'Geometry Wall Type', 'Geometry Building Horizontal Location MF', 'Duct Leakage and Insulation', 'Heating Setpoint Offset Period', 'Geometry Building Type Height', 'HVAC Heating Type And Fuel', 'Geometry Building Number Units MF', 'Geometry Story Bin', 'Windows', 'Heating Setpoint', 'Geometry Building Level MF', 'Misc Pool', 'Insulation Roof', 'Misc Freezer', 'Insulation Wall'}
# iter: 6, known_cap_cols: {'Clothes Washer Usage Level', 'Cooling Setpoint Has Offset', 'Cooling Setpoint', 'Census Division RECS', 'Vintage', 'HVAC Shared Efficiencies', 'Usage Level', 'Cooking Range Usage Level', 'Water Heater In Unit', 'HVAC Has Zonal Electric Heating', 'Hot Water Fixtures', 'HVAC Has Shared System', 'Cooling Setpoint Offset Magnitude', 'Geometry Building Horizontal Location SFA', 'Ceiling Fan', 'Misc Gas Grill', 'County', 'Income', 'Location Region', 'Income RECS2015', 'State', 'Insulation Floor', 'Clothes Dryer Usage Level', 'Heating Fuel', 'County and PUMA', 'HVAC Cooling Type', 'Geometry Building Type ACS', 'Insulation Rim Joist', 'Misc Gas Fireplace', 'Geometry Floor Area Bin', 'ASHRAE IECC Climate Zone 2004', 'Neighbors', 'Roof Material', 'Water Heater Efficiency', 'Radiant Barrier', 'Income RECS2020', 'Vintage ACS', 'Geometry Building Type RECS', 'HVAC Heating Type', 'Tenure', 'Range Spot Vent Hour', 'Orientation', 'Corridor', 'Has PV', 'HVAC Has Ducts', 'Cooling Setpoint Offset Period', 'PUMA Metro Status', 'PV System Size', 'Water Heater Fuel', 'HVAC Heating Efficiency', 'Misc Well Pump', 'Census Division', 'Geometry Floor Area', 'Insulation Slab', 'Bedrooms', 'Lighting', 'Insulation Foundation Wall', 'Geometry Building Number Units SFA', 'Bathroom Spot Vent Hour', 'Refrigerator Usage Level', 'Vacancy Status', 'PUMA', 'Misc Gas Lighting', 'PV Orientation', 'Geometry Foundation Type'}
# iter: 7, needed_cap_cols: {'Clothes Dryer', 'Refrigerator', 'Misc Pool Pump', 'Window Areas', 'Clothes Washer', 'Heating Setpoint Offset Magnitude', 'Misc Pool Heater', 'Duct Location', 'Duct Leakage and Insulation', 'Heating Setpoint Offset Period', 'Misc Pool', 'Misc Freezer', 'Insulation Wall'}
# iter: 7, known_cap_cols: {'Clothes Washer Usage Level', 'Dishwasher', 'Heating Setpoint Has Offset', 'Misc Extra Refrigerator', 'Misc Gas Grill', 'Geometry Garage', 'Clothes Washer Presence', 'State', 'Occupants', 'Clothes Dryer Usage Level', 'Geometry Building Type ACS', 'Geometry Floor Area Bin', 'ASHRAE IECC Climate Zone 2004', 'HVAC Cooling Efficiency', 'Income RECS2020', 'Vintage ACS', 'Geometry Building Type RECS', 'Tenure', 'HVAC Has Ducts', 'Has PV', 'PV System Size', 'Water Heater Fuel', 'Geometry Wall Exterior Finish', 'Geometry Stories Low Rise', 'Bathroom Spot Vent Hour', 'PUMA', 'Misc Gas Lighting', 'Geometry Foundation Type', 'Cooling Setpoint Has Offset', 'Cooling Setpoint', 'Misc Hot Tub Spa', 'Usage Level', 'Water Heater In Unit', 'Federal Poverty Level', 'HVAC Has Zonal Electric Heating', 'Income', 'Geometry Stories', 'Infiltration', 'Income RECS2015', 'County and PUMA', 'HVAC Cooling Type', 'Insulation Rim Joist', 'Neighbors', 'Water Heater Efficiency', 'Roof Material', 'Insulation Ceiling', 'Radiant Barrier', 'Cooking Range', 'Household Has Tribal Persons', 'PUMA Metro Status', 'Census Division', 'Geometry Building Number Units SFA', 'Refrigerator Usage Level', 'Geometry Attic Type', 'Vintage', 'HVAC Shared Efficiencies', 'HVAC Cooling Partial Space Conditioning', 'Cooking Range Usage Level', 'Geometry Wall Type', 'HVAC Has Shared System', 'Geometry Building Horizontal Location MF', 'Cooling Setpoint Offset Magnitude', 'Geometry Building Horizontal Location SFA', 'Ceiling Fan', 'County', 'HVAC Heating Type', 'Geometry Building Type Height', 'HVAC Heating Type And Fuel', 'Cooling Setpoint Offset Period', 'HVAC Heating Efficiency', 'Geometry Building Number Units MF', 'Geometry Story Bin', 'Insulation Slab', 'Lighting', 'Windows', 'Vacancy Status', 'Heating Setpoint', 'Geometry Building Level MF', 'Census Division RECS', 'Hot Water Fixtures', 'Location Region', 'Insulation Floor', 'Heating Fuel', 'Misc Gas Fireplace', 'Insulation Roof', 'Range Spot Vent Hour', 'Orientation', 'Corridor', 'Misc Well Pump', 'Geometry Floor Area', 'Bedrooms', 'Insulation Foundation Wall', 'PV Orientation'}
# iter: 8, needed_cap_cols: {'Duct Leakage and Insulation'}
# iter: 8, known_cap_cols: {'Clothes Washer Usage Level', 'Dishwasher', 'Heating Setpoint Has Offset', 'Misc Extra Refrigerator', 'Clothes Dryer', 'Misc Gas Grill', 'Geometry Garage', 'Clothes Washer Presence', 'State', 'Occupants', 'Clothes Dryer Usage Level', 'Geometry Building Type ACS', 'Geometry Floor Area Bin', 'ASHRAE IECC Climate Zone 2004', 'HVAC Cooling Efficiency', 'Income RECS2020', 'Vintage ACS', 'Geometry Building Type RECS', 'Refrigerator', 'Tenure', 'HVAC Has Ducts', 'Has PV', 'PV System Size', 'Water Heater Fuel', 'Misc Pool Pump', 'Geometry Wall Exterior Finish', 'Geometry Stories Low Rise', 'Bathroom Spot Vent Hour', 'PUMA', 'Misc Gas Lighting', 'Geometry Foundation Type', 'Cooling Setpoint Has Offset', 'Cooling Setpoint', 'Misc Hot Tub Spa', 'Usage Level', 'Water Heater In Unit', 'Federal Poverty Level', 'HVAC Has Zonal Electric Heating', 'Income', 'Geometry Stories', 'Infiltration', 'Income RECS2015', 'County and PUMA', 'HVAC Cooling Type', 'Insulation Rim Joist', 'Neighbors', 'Water Heater Efficiency', 'Roof Material', 'Insulation Ceiling', 'Radiant Barrier', 'Cooking Range', 'Household Has Tribal Persons', 'PUMA Metro Status', 'Census Division', 'Window Areas', 'Geometry Building Number Units SFA', 'Refrigerator Usage Level', 'Clothes Washer', 'Geometry Attic Type', 'Heating Setpoint Offset Magnitude', 'Misc Pool Heater', 'Duct Location', 'Vintage', 'HVAC Shared Efficiencies', 'HVAC Cooling Partial Space Conditioning', 'Cooking Range Usage Level', 'Geometry Wall Type', 'HVAC Has Shared System', 'Geometry Building Horizontal Location MF', 'Cooling Setpoint Offset Magnitude', 'Geometry Building Horizontal Location SFA', 'Ceiling Fan', 'County', 'HVAC Heating Type', 'Heating Setpoint Offset Period', 'Geometry Building Type Height', 'HVAC Heating Type And Fuel', 'Cooling Setpoint Offset Period', 'HVAC Heating Efficiency', 'Geometry Building Number Units MF', 'Geometry Story Bin', 'Insulation Slab', 'Lighting', 'Windows', 'Vacancy Status', 'Heating Setpoint', 'Geometry Building Level MF', 'Census Division RECS', 'Hot Water Fixtures', 'Misc Pool', 'Location Region', 'Insulation Floor', 'Heating Fuel', 'Misc Gas Fireplace', 'Insulation Roof', 'Range Spot Vent Hour', 'Orientation', 'Corridor', 'Misc Freezer', 'Misc Well Pump', 'Geometry Floor Area', 'Bedrooms', 'Insulation Foundation Wall', 'Insulation Wall', 'PV Orientation'}

# %%
import polars as pl
import pandas as pd

sample_df = pl.read_csv('sample_test.csv')
column_plan_df = pd.read_csv('column_plan.csv')
model_cols = column_plan_df.loc[
    (column_plan_df['keep_for_model'] == 'Yes') | 
    (column_plan_df['keep_for_model'] == 'Split')
]['field_name'].to_list()
sample_not_cp = set(sample_df.columns) - set(model_cols)
print(f'In sample but not needed for model: {sample_not_cp}')

cp_not_sample = set(model_cols) - set(sample_df.columns)
print(f'Needed for model but not in sample: {cp_not_sample}')
if not(cp_not_sample or sample_not_cp):
    print('PASS')
# Out:
# In sample but not needed for model: set()
# Needed for model but not in sample: set()
# PASS

# %%
##  Checking if sample gives expected enumerations
import polars as pl
import pandas as pd

sample_df = pd.read_csv('sample_test.csv', keep_default_na=False, dtype='str',)
column_plan_df = pd.read_csv('column_plan.csv', keep_default_na=False, dtype='str',)
model_cols = column_plan_df.loc[
    (column_plan_df['keep_for_model'] == 'Yes') | 
    (column_plan_df['keep_for_model'] == 'Split')
]['field_name'].to_list()

model_enumerations = column_plan_df.loc[
    (column_plan_df['keep_for_model'] == 'Yes') | 
    (column_plan_df['keep_for_model'] == 'Split')
]['actual_enumerations'].to_list()

model_enumerations_dict = {}
for i, col in enumerate(model_cols):
    model_enumerations_dict[col] = model_enumerations[i].split("|")

sample_enumerations_dict = {}
for col in sample_df.columns:
    sample_enumerations_dict[col] = sample_df[col].astype(str).unique().tolist()

for key in model_enumerations_dict:
    if sorted(model_enumerations_dict[key]) == sorted(sample_enumerations_dict[key]):
        # print(f'{key} matches')
        pass
    else:
        print(f'{key}:')
        sample_set = set(sample_enumerations_dict[key])
        model_set = set(model_enumerations_dict[key])
        samp_not_mod = sample_set - model_set
        mod_not_samp = model_set - sample_set
        if samp_not_mod:
            print(f'In sample but not model: {samp_not_mod}')
        # Would not expect this to have all counties and states
        if mod_not_samp and key!="in.county" and key!="in.state":
            print(f'In model but not sample: {mod_not_samp}')
# Everything left is sufficiently rare that it is not surprising to not see them in a sample of 1000
# Out:
# in.cooking_range:
# In model but not sample: {'None'}
# in.cooling_setpoint_offset_period:
# In model but not sample: {'Day Setup and Night Setback +5h', 'Day and Night Setup +5h', 'Day and Night Setup -1h', 'Day and Night Setup -3h', 'Day and Night Setup -4h', 'Day and Night Setup +3h', 'Day Setup and Night Setback -4h', 'Day Setup +3h', 'Day and Night Setup -5h', 'Day and Night Setup +2h', 'Day and Night Setup +1h', 'Day Setup and Night Setback -5h'}
# in.county:
# in.geometry_building_number_units_mf:
# In model but not sample: {'17', '13', '19'}
# in.geometry_building_number_units_sfa:
# In model but not sample: {'60', '24', '15'}
# in.geometry_stories:
# In model but not sample: {'21', '10', '8', '11', '7', '9', '13'}
# in.geometry_wall_exterior_finish:
# In model but not sample: {'Brick, Light', 'Stucco, Medium/Dark'}
# in.heating_setpoint_offset_period:
# In model but not sample: {'Day +1h', 'Day and Night -3h', 'Day -3h', 'Day -5h'}
# in.hvac_cooling_efficiency:
# In model but not sample: {'Room AC, EER 8.5'}
# in.hvac_cooling_partial_space_conditioning:
# In model but not sample: {'<10% Conditioned'}
# in.hvac_heating_efficiency:
# In model but not sample: {'MSHP, SEER 29.3, 14 HSPF', 'Fuel Boiler, 80% AFUE', 'Fuel Furnace, 60% AFUE', 'Fuel Boiler, 90% AFUE'}
# in.hvac_heating_type_and_fuel:
# In model but not sample: {'Fuel Oil Fuel Boiler', 'Fuel Oil Shared Heating', 'Fuel Oil Fuel Wall/Floor Furnace', 'Propane Shared Heating', 'Other Fuel Shared Heating', 'Other Fuel Fuel Boiler', 'Propane Fuel Boiler', 'Other Fuel Fuel Furnace'}
# in.infiltration:
# In model but not sample: {'1 ACH50'}
# in.insulation_ceiling:
# In model but not sample: {'R-49'}
# in.insulation_floor:
# In model but not sample: {'Ceiling R-30'}
# in.occupants:
# In model but not sample: {'10+'}
# in.pv_orientation:
# In model but not sample: {'Northwest', 'North', 'Northeast', 'West', 'Southeast'}
# in.pv_system_size:
# In model but not sample: {'13.0 kWDC', '1.0 kWDC', '11.0 kWDC', '7.0 kWDC'}
# in.state:
# in.water_heater_efficiency:
# In model but not sample: {'Fuel Oil Premium', 'Fuel Oil Standard', 'FIXME Fuel Oil Indirect'}
# in.water_heater_fuel:
# In model but not sample: {'Fuel Oil'}

# %%
import geopandas as gpd

# gdf = gpd.read_file('/home/casey/Downloads/ipums_puma_2020/ipums_puma_2020.shp')
# gdf = gpd.read_file('/home/casey/Downloads/ipums_puma_2010_tl20/ipums_puma_2010_tl20.shp')
gdf = gpd.read_file('/home/casey/Downloads/ipums_puma_2010/ipums_puma_2010.shp')

# gdf['Gisjoin and PUMA'] = gdf['GISJOIN'] + ", " + gdf["PUMA"]
# gdf['County Code'] = gdf['GISJOIN'][5:8]
gdf = gdf.loc[~gdf['State'].isin(['Alaska', 'Hawaii'])]
gdf = gdf.drop(['GISMATCH', 'GISJOIN', 'STATEFIP', 'PUMA'],axis=1)
gdf['Name'] = gdf['Name'].str.replace(' PUMA', '')
print(gdf.shape[0])
print(len(gdf['Name'].unique()))
print(gdf.head())
# '''
for state in gdf['State'].unique():
    gdf_at_state = gdf.loc[gdf['State'] == state]
    map = gdf_at_state.explore(min_lat=20,
        min_lon=-140,
        max_lat=50,
        max_lon=-60,
        max_bounds=True,)
    map.save(f'maps/{state}_map.html')
    # break
# '''
# Out:
# 2363
# 2358
#      GEOID       State                                               Name  \
# 0  0600105  California  Alameda County (West)--San Leandro, Alameda & ...
# 1  0600102  California  Alameda County (Northwest)--Oakland (Northwest...
# 2  0608502  California  Santa Clara County (Northwest)--Sunnyvale & Sa...
# 3  0600108  California  Alameda County (Southwest)--Union City, Newark...
# 4  0600107  California             Alameda County (Central)--Hayward City
#
#                                             geometry
# 0  MULTIPOLYGON (((-2258646.53 342733.341, -22586...
# 1  POLYGON ((-2259099.372 353383.127, -2259101.40...
# 2  POLYGON ((-2246220.131 304622.39, -2246216.047...
# 3  MULTIPOLYGON (((-2247215.331 305414.315, -2247...
# 4  POLYGON ((-2244205.948 331582.334, -2244209.13...

# %%
gdf = gpd.read_file('/home/casey/Downloads/ipums_puma_2010/ipums_puma_2010.shp')
print(gdf[(gdf['PUMA'] == '03201') & (gdf['State'] == 'Tennessee')])
# Out:
#      GISMATCH    GISJOIN    GEOID STATEFIP      State   PUMA  \
# 488   4703201  G47003201  4703201       47  Tennessee  03201
#
#                                       Name  \
# 488  Memphis City (Central Riverside) PUMA
#
#                                               geometry
# 488  POLYGON ((544659.937 -242210.94, 544660.368 -2...

# %%
import json
gdf = gpd.read_file('/home/casey/Downloads/ipums_puma_2010/ipums_puma_2010.shp')

states = gdf['State'].unique()
states = set(states) - {'Puerto Rico', 'Alaska', 'Hawaii'}
print(len(states))
print(sorted(list(states)))
with open("states.json", "w") as f:
    json.dump(sorted(list(states)), f)
# Out:
# 49
# ['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
